# %% [markdown]
# # Help Chat
#
# **Use natural language to query Help Centre**

# %% [markdown]
# ## Fetch Data from Web Source

# %% [markdown]
# #### Utility functions

# %%
import re

"""
Function to clean text from web pages
"""
def clean_text(text: str):
    # Normalize line breaks to \n\n (two new lines)
    text = text.replace("\r\n", "\n\n")
    text = text.replace("\r", "\n\n")

    # Replace two or more spaces with a single space
    text = re.sub(" {2,}", " ", text)

    # Remove leading spaces before removing trailing spaces
    text = re.sub("^[ \t]+", "", text, flags=re.MULTILINE)

    # Remove trailing spaces before removing empty lines
    text = re.sub("[ \t]+$", "", text, flags=re.MULTILINE)

    # Remove empty lines
    text = re.sub("^\s+", "", text, flags=re.MULTILINE)

    return text

# %%
import tiktoken

"""
Function to calculate the number of tokens in a text string.
"""

encoding = tiktoken.get_encoding("cl100k_base")

def num_tokens_from_string(string: str) -> int:
    num_tokens = len(encoding.encode(string))
    return num_tokens

# %% [markdown]
# #### Get data files
#
# We load a number of HTML pages using the LangChain WebBaseLoader. Each of those pages contains lots of superfluous content so we extract only the relevant article context.

# %%
# read urls from txt file
with open('help_urls.txt') as f:
    urls = f.readlines()

# for debugging
#urls = ["/help/disaster-help/disaster-preparation/"]


# remove whitespace characters like `\n` at the end of each line
urls = [x.strip() for x in urls]

# prepend Root URL to each url
urls = ["https://www.westpac.com.au" + x for x in urls]

display(urls)
# Out:
# ['https://www.westpac.com.au/about-westpac',
#  'https://www.westpac.com.au/about-westpac/careers',
#  'https://www.westpac.com.au/about-westpac/global-locations',
#  'https://www.westpac.com.au/about-westpac/inclusion-and-diversity',
#  'https://www.westpac.com.au/about-westpac/indigenous',
#  'https://www.westpac.com.au/about-westpac/innovation',
#  'https://www.westpac.com.au/about-westpac/investor-centre',
#  'https://www.westpac.com.au/about-westpac/media',
#  'https://www.westpac.com.au/about-westpac/our-foundations',
#  'https://www.westpac.com.au/about-westpac/sustainability',
#  'https://www.westpac.com.au/about-westpac/sustainability/initiatives-for-you/indigenous-banking',
#  'https://www.westpac.com.au/about-westpac/sustainability/our-positions-and-perspectives/difficult-circumstances',
#  'https://www.westpac.com.au/about-westpac/westpac-group',
#  'https://www.westpac.com.au/about-westpac/westpac-wire',
#  'https://www.westpac.com.au/business-banking',
#  'https://www.westpac.com.au/business-banking/bank-accounts',
#  'https://www.westpac.com.au/business-banking/business-help',
#  'https://www.westpac.com.au/business-banking/credit-cards',
#  'https://www.westpac.com.au/business-banking/current-offers',
#  'https://www.westpac.com.au/business-banking/industries',
#  'https://www.westpac.com.au/business-banking/industries/agribusiness',
#  'https://www.westpac.com.au/business-banking/insurance',
#  'https://www.westpac.com.au/business-banking/international-trade',
#  'https://www.westpac.com.au/business-banking/loans-finance',
#  'https://www.westpac.com.au/business-banking/merchants-and-payments',
#  'https://www.westpac.com.au/business-banking/online-banking',
#  'https://www.westpac.com.au/business-banking/online-banking/support-faqs',
#  'https://www.westpac.com.au/business-banking/savings-accounts',
#  'https://www.westpac.com.au/business-banking/term-deposits',
#  'https://www.westpac.com.au/contact-us',
#  'https://www.westpac.com.au/contact-us/feedback-complaints',
#  'https://www.westpac.com.au/corporate-banking',
#  'https://www.westpac.com.au/corporate-banking/corporate-and-structured-finance',
#  'https://www.westpac.com.au/corporate-banking/corporate-institutional',
#  'https://www.westpac.com.au/corporate-banking/corporate-online',
#  'https://www.westpac.com.au/corporate-banking/esg-environmental-social-governance',
#  'https://www.westpac.com.au/corporate-banking/financial-markets',
#  'https://www.westpac.com.au/corporate-banking/trade-supply-chain-finance',
#  'https://www.westpac.com.au/corporate-banking/transactional-banking',
#  'https://www.westpac.com.au/corporate-banking/westpaciq',
#  'https://www.westpac.com.au/faq/',
#  'https://www.westpac.com.au/faq/4-digit-passcode-security',
#  'https://www.westpac.com.au/faq/4-digit-passcode-storage',
#  'https://www.westpac.com.au/faq/access-account-overseas',
#  'https://www.westpac.com.au/faq/access-contacts',
#  'https://www.westpac.com.au/faq/access-money-in-australia',
#  'https://www.westpac.com.au/faq/account-overview',
#  'https://www.westpac.com.au/faq/activate-my-card',
#  'https://www.westpac.com.au/faq/alexa',
#  'https://www.westpac.com.au/faq/alexa-account-compromised',
#  'https://www.westpac.com.au/faq/alexa-additional-questions',
#  'https://www.westpac.com.au/faq/alexa-amazon-echo-not-working',
#  'https://www.westpac.com.au/faq/alexa-eligible-accounts',
#  'https://www.westpac.com.au/faq/alexa-enable-skill',
#  'https://www.westpac.com.au/faq/alexa-how-many-skills',
#  'https://www.westpac.com.au/faq/alexa-how-to-use',
#  'https://www.westpac.com.au/faq/alexa-passcode',
#  'https://www.westpac.com.au/faq/alexa-payments',
#  'https://www.westpac.com.au/faq/alexa-protect-info',
#  'https://www.westpac.com.au/faq/alexa-trouble-enabling',
#  'https://www.westpac.com.au/faq/alexa-unlink-skill',
#  'https://www.westpac.com.au/faq/alexa-what-devices',
#  'https://www.westpac.com.au/faq/alexa-what-info-collected',
#  'https://www.westpac.com.au/faq/alexa-what-is-it',
#  'https://www.westpac.com.au/faq/alexa-who-can-access',
#  'https://www.westpac.com.au/faq/altitude-rewards',
#  'https://www.westpac.com.au/faq/android-pay',
#  'https://www.westpac.com.au/faq/android-pay-add-card',
#  'https://www.westpac.com.au/faq/android-pay-backup',
#  'https://www.westpac.com.au/faq/android-pay-card-expired',
#  'https://www.westpac.com.au/faq/android-pay-card-removed',
#  'https://www.westpac.com.au/faq/android-pay-charge',
#  'https://www.westpac.com.au/faq/android-pay-deleted-app',
#  'https://www.westpac.com.au/faq/android-pay-fitbit',
#  'https://www.westpac.com.au/faq/android-pay-internet-connection',
#  'https://www.westpac.com.au/faq/android-pay-lost-stolen',
#  'https://www.westpac.com.au/faq/android-pay-masked-number',
#  'https://www.westpac.com.au/faq/android-pay-more-information',
#  'https://www.westpac.com.au/faq/android-pay-new-device',
#  'https://www.westpac.com.au/faq/android-pay-reissued-card',
#  'https://www.westpac.com.au/faq/android-pay-remove-suspend-card',
#  'https://www.westpac.com.au/faq/android-pay-secure',
#  'https://www.westpac.com.au/faq/android-pay-sharing-personal-information',
#  'https://www.westpac.com.au/faq/android-pay-spending-limits-pin',
#  'https://www.westpac.com.au/faq/android-pay-transaction-declined',
#  'https://www.westpac.com.au/faq/android-pay-transaction-selection',
#  'https://www.westpac.com.au/faq/android-pay-verify-card',
#  'https://www.westpac.com.au/faq/android-pay-virtual-account-number',
#  'https://www.westpac.com.au/faq/android-pay-what-is-it',
#  'https://www.westpac.com.au/faq/android-pay-which-cards-eligible',
#  'https://www.westpac.com.au/faq/android-pay-which-devices',
#  'https://www.westpac.com.au/faq/annual-card-fee-date',
#  'https://www.westpac.com.au/faq/apple-pay',
#  'https://www.westpac.com.au/faq/apple-pay-accepted-payments',
#  'https://www.westpac.com.au/faq/apple-pay-access-chq-sav',
#  'https://www.westpac.com.au/faq/apple-pay-add-app',
#  'https://www.westpac.com.au/faq/apple-pay-add-card',
#  'https://www.westpac.com.au/faq/apple-pay-add-from-westpac-live-banking-app',
#  'https://www.westpac.com.au/faq/apple-pay-additional-card-holders',
#  'https://www.westpac.com.au/faq/apple-pay-additional-fees',
#  'https://www.westpac.com.au/faq/apple-pay-buis-card-elig',
#  'https://www.westpac.com.au/faq/apple-pay-card-number',
#  'https://www.westpac.com.au/faq/apple-pay-card-reenrol',
#  'https://www.westpac.com.au/faq/apple-pay-cash-out',
#  'https://www.westpac.com.au/faq/apple-pay-compatible-devices',
#  'https://www.westpac.com.au/faq/apple-pay-complete-verification',
#  'https://www.westpac.com.au/faq/apple-pay-device-account-number',
#  'https://www.westpac.com.au/faq/apple-pay-device-registration',
#  'https://www.westpac.com.au/faq/apple-pay-dispute-trans',
#  'https://www.westpac.com.au/faq/apple-pay-eligible-cards',
#  'https://www.westpac.com.au/faq/apple-pay-get-info',
#  'https://www.westpac.com.au/faq/apple-pay-handy-card',
#  'https://www.westpac.com.au/faq/apple-pay-lost-stolen-card',
#  'https://www.westpac.com.au/faq/apple-pay-lost-stolen-device',
#  'https://www.westpac.com.au/faq/apple-pay-loyatly-schemes',
#  'https://www.westpac.com.au/faq/apple-pay-making-payments',
#  'https://www.westpac.com.au/faq/apple-pay-mcard-tt',
#  'https://www.westpac.com.au/faq/apple-pay-minimum-age',
#  'https://www.westpac.com.au/faq/apple-pay-multiple-cards',
#  'https://www.westpac.com.au/faq/apple-pay-opal',
#  'https://www.westpac.com.au/faq/apple-pay-payment-network',
#  'https://www.westpac.com.au/faq/apple-pay-personal-info',
#  'https://www.westpac.com.au/faq/apple-pay-pin-requirements',
#  'https://www.westpac.com.au/faq/apple-pay-removing-card',
#  'https://www.westpac.com.au/faq/apple-pay-reward-points',
#  'https://www.westpac.com.au/faq/apple-pay-security',
#  'https://www.westpac.com.au/faq/apple-pay-selling-device',
#  'https://www.westpac.com.au/faq/apple-pay-set-default-card',
#  'https://www.westpac.com.au/faq/apple-pay-tandc',
#  'https://www.westpac.com.au/faq/apple-pay-transaction-limits',
#  'https://www.westpac.com.au/faq/apple-pay-transactions-declining',
#  'https://www.westpac.com.au/faq/apple-pay-travel-overseas',
#  'https://www.westpac.com.au/faq/apple-pay-view-trans',
#  'https://www.westpac.com.au/faq/apple-pay-with-handycard',
#  'https://www.westpac.com.au/faq/apple-pay-with-mastercard',
#  'https://www.westpac.com.au/faq/apple-watch-quick-balance',
#  'https://www.westpac.com.au/faq/apple-watch-refresh-quick-balance',
#  'https://www.westpac.com.au/faq/application-declined',
#  'https://www.westpac.com.au/faq/authorise-changes',
#  'https://www.westpac.com.au/faq/autopay-balance-transfer',
#  'https://www.westpac.com.au/faq/autopay-cancel',
#  'https://www.westpac.com.au/faq/autopay-change-options',
#  'https://www.westpac.com.au/faq/autopay-closing-balance',
#  'https://www.westpac.com.au/faq/autopay-extra-repayments',
#  'https://www.westpac.com.au/faq/autopay-not-enough-fund',
#  'https://www.westpac.com.au/faq/autopay-overdue',
#  'https://www.westpac.com.au/faq/autopay-smart-plan',
#  'https://www.westpac.com.au/faq/autopay-when-start',
#  'https://www.westpac.com.au/faq/bank-details-international-money-transfer',
#  'https://www.westpac.com.au/faq/beem-it',
#  'https://www.westpac.com.au/faq/beem-it-app-issue',
#  'https://www.westpac.com.au/faq/beem-it-how-to-get-it',
#  'https://www.westpac.com.au/faq/beem-it-sign-in',
#  'https://www.westpac.com.au/faq/beem-it-what-is-it',
#  'https://www.westpac.com.au/faq/bpay-view',
#  'https://www.westpac.com.au/faq/break-term-deposit-contract-before-maturity',
#  'https://www.westpac.com.au/faq/business-how-can-i-manage-the-signatories-account',
#  'https://www.westpac.com.au/faq/business-how-can-i-view-estatement',
#  'https://www.westpac.com.au/faq/business-how-connect-bank-feeds',
#  'https://www.westpac.com.au/faq/business-how-do-i-change-user-daily-payment',
#  'https://www.westpac.com.au/faq/business-how-do-i-setup-new-user',
#  'https://www.westpac.com.au/faq/business-how-do-reset-business-password',
#  'https://www.westpac.com.au/faq/business-how-export-detailed-transaction-history',
#  'https://www.westpac.com.au/faq/business-how-order-bank-cheque-online',
#  'https://www.westpac.com.au/faq/business-how-upload-file-payment-MYOB',
#  'https://www.westpac.com.au/faq/business-import-payment-details',
#  'https://www.westpac.com.au/faq/business-importing-payment-file',
#  'https://www.westpac.com.au/faq/business-online-banking',
#  'https://www.westpac.com.au/faq/business-payments-limits',
#  'https://www.westpac.com.au/faq/business-what-can-i-do-online-banking',
#  'https://www.westpac.com.au/faq/business-what-features-available-business-customers-app',
#  'https://www.westpac.com.au/faq/business-what-if-dont-respond-tax-residency-business',
#  'https://www.westpac.com.au/faq/business-what-is-secure-id',
#  'https://www.westpac.com.au/faq/business-what-transfer-limits-for-accounts',
#  'https://www.westpac.com.au/faq/business-why-cant-sign-mobile-banking',
#  'https://www.westpac.com.au/faq/can-an-additional-cardholder-get-a-partpay-card',
#  'https://www.westpac.com.au/faq/can-i-change-or-defer-my-partpay-payments',
#  'https://www.westpac.com.au/faq/can-i-negotiate-a-better-exchange-rate',
#  'https://www.westpac.com.au/faq/can-i-transfer-a-purchase-from-my-linked-card-to-my-partpay-card',
#  'https://www.westpac.com.au/faq/can-using-partpay-impact-my-credit-report',
#  'https://www.westpac.com.au/faq/cant-see-closed-account-statements',
#  'https://www.westpac.com.au/faq/carbon-footprint-tracker',
#  'https://www.westpac.com.au/faq/carbon-footprint-tracker-calculation',
#  'https://www.westpac.com.au/faq/carbon-footprint-tracker-calculation-accuracy',
#  'https://www.westpac.com.au/faq/carbon-footprint-tracker-calculation-estimate',
#  'https://www.westpac.com.au/faq/carbon-footprint-tracker-calculation-westpac',
#  'https://www.westpac.com.au/faq/carbon-footprint-tracker-carbon-footprint',
#  'https://www.westpac.com.au/faq/carbon-footprint-tracker-change-transaction',
#  'https://www.westpac.com.au/faq/carbon-footprint-tracker-co2-equivalent-measure',
#  'https://www.westpac.com.au/faq/carbon-footprint-tracker-comparison',
#  'https://www.westpac.com.au/faq/carbon-footprint-tracker-data-privacy',
#  'https://www.westpac.com.au/faq/carbon-footprint-tracker-eligible-products',
#  'https://www.westpac.com.au/faq/carbon-footprint-tracker-exclude-account-from-view',
#  'https://www.westpac.com.au/faq/carbon-footprint-tracker-filter-categories',
#  'https://www.westpac.com.au/faq/carbon-footprint-tracker-foreign-currency-calculation',
#  'https://www.westpac.com.au/faq/carbon-footprint-tracker-hide',
#  'https://www.westpac.com.au/faq/carbon-footprint-tracker-insight',
#  'https://www.westpac.com.au/faq/carbon-footprint-tracker-learn',
#  'https://www.westpac.com.au/faq/carbon-footprint-tracker-lifestyle-choices',
#  'https://www.westpac.com.au/faq/carbon-footprint-tracker-lower-carbon-footprint',
#  'https://www.westpac.com.au/faq/carbon-footprint-tracker-mortgage-loan-repayments',
#  'https://www.westpac.com.au/faq/carbon-footprint-tracker-positive-expense',
#  'https://www.westpac.com.au/faq/carbon-footprint-tracker-seeing-closed-accounts',
#  'https://www.westpac.com.au/faq/carbon-footprint-tracker-seeing-old-accounts',
#  'https://www.westpac.com.au/faq/carbon-footprint-tracker-transaction-categories',
#  'https://www.westpac.com.au/faq/carbon-footprint-tracker-transactions-missing',
#  'https://www.westpac.com.au/faq/carbon-footprint-tracker-understand-my-carbon-footprint',
#  'https://www.westpac.com.au/faq/card-activation-additional-cardholders',
#  'https://www.westpac.com.au/faq/card-activation-camera-capture',
#  'https://www.westpac.com.au/faq/card-activation-secure',
#  'https://www.westpac.com.au/faq/card-activation-what-else-to-do',
#  'https://www.westpac.com.au/faq/card-activation-without-app',
#  'https://www.westpac.com.au/faq/cardless-cash-how-does-it-work',
#  'https://www.westpac.com.au/faq/cardless-cash-phone-lost-stolen',
#  'https://www.westpac.com.au/faq/cardless-cash-secure',
#  'https://www.westpac.com.au/faq/cardless-cash-supported-smartphones',
#  'https://www.westpac.com.au/faq/cardless-cash-to-others',
#  'https://www.westpac.com.au/faq/cardless-cash-what-is-it',
#  'https://www.westpac.com.au/faq/cardless-cash-who-is-eligible',
#  'https://www.westpac.com.au/faq/cardless-cash-withdraw-without-card',
#  'https://www.westpac.com.au/faq/change-current-creditcard-to-different-card',
#  'https://www.westpac.com.au/faq/change-daily-payment-limit',
#  'https://www.westpac.com.au/faq/change-details-mobile-banking',
#  'https://www.westpac.com.au/faq/change-details-new/',
#  'https://www.westpac.com.au/faq/change-mobile-number',
#  'https://www.westpac.com.au/faq/change-name',
#  'https://www.westpac.com.au/faq/change-payment-limit',
#  'https://www.westpac.com.au/faq/change-recurring-payments',
#  'https://www.westpac.com.au/faq/change-scheduled-payment',
#  'https://www.westpac.com.au/faq/check-security-code',
#  'https://www.westpac.com.au/faq/cheque-deposit',
#  'https://www.westpac.com.au/faq/cheque-deposit-after-submit',
#  'https://www.westpac.com.au/faq/cheque-deposit-appear-in-account',
#  'https://www.westpac.com.au/faq/cheque-deposit-bank-statement',
#  'https://www.westpac.com.au/faq/cheque-deposit-cheque-dishonoured',
#  'https://www.westpac.com.au/faq/cheque-deposit-cheques-daily-limit',
#  'https://www.westpac.com.au/faq/cheque-deposit-clearance',
#  'https://www.westpac.com.au/faq/cheque-deposit-creditcard-deposit',
#  'https://www.westpac.com.au/faq/cheque-deposit-different-cheques',
#  'https://www.westpac.com.au/faq/cheque-deposit-how-to-access',
#  'https://www.westpac.com.au/faq/cheque-deposit-incorrect-amount',
#  'https://www.westpac.com.au/faq/cheque-deposit-not-showing',
#  'https://www.westpac.com.au/faq/cheque-deposit-public-holiday',
#  'https://www.westpac.com.au/faq/cheque-deposit-rejected',
#  'https://www.westpac.com.au/faq/cheque-deposit-rejected-deposit',
#  'https://www.westpac.com.au/faq/cheque-deposit-sms-notification',
#  'https://www.westpac.com.au/faq/close-account',
#  'https://www.westpac.com.au/faq/close-credit-card',
#  'https://www.westpac.com.au/faq/close-savings-account',
#  'https://www.westpac.com.au/faq/close-term-deposit',
#  'https://www.westpac.com.au/faq/contact-us-in-app',
#  'https://www.westpac.com.au/faq/credit-card-expires',
#  'https://www.westpac.com.au/faq/credit-card-fraud',
#  'https://www.westpac.com.au/faq/credit-card-interest-rates',
#  'https://www.westpac.com.au/faq/credit-card-reminder-delete-or-change-app',
#  'https://www.westpac.com.au/faq/credit-card-reminder-delete-or-change-online-banking',
#  'https://www.westpac.com.au/faq/credit-card-reminder-fees',
#  'https://www.westpac.com.au/faq/credit-card-reminder-out-of-cycle-payment',
#  'https://www.westpac.com.au/faq/credit-card-reminder-set-up-app',
#  'https://www.westpac.com.au/faq/credit-card-reminder-set-up-online-banking',
#  'https://www.westpac.com.au/faq/credit-card-reminder-what-is-it',
#  'https://www.westpac.com.au/faq/credit-cards',
#  'https://www.westpac.com.au/faq/customer-id',
#  'https://www.westpac.com.au/faq/cut-off-times',
#  'https://www.westpac.com.au/faq/debitcard-daily-limit',
#  'https://www.westpac.com.au/faq/deceased-estate-additional-expenses',
#  'https://www.westpac.com.au/faq/deceased-estate-bills-from-estate',
#  'https://www.westpac.com.au/faq/deceased-estate-close-the-accounts',
#  'https://www.westpac.com.au/faq/deceased-estate-death-certificate',
#  'https://www.westpac.com.au/faq/deceased-estate-funds-to-be-released',
#  'https://www.westpac.com.au/faq/deceased-estate-funeral-expenses',
#  'https://www.westpac.com.au/faq/deceased-estate-identified-by-westpac',
#  'https://www.westpac.com.au/faq/deceased-estate-letters-of-administration',
#  'https://www.westpac.com.au/faq/deceased-estate-mail-to-deceased',
#  'https://www.westpac.com.au/faq/deceased-estate-no-will',
#  'https://www.westpac.com.au/faq/deceased-estate-power-of-attorney',
#  'https://www.westpac.com.au/faq/deceased-estate-safe-custody',
#  'https://www.westpac.com.au/faq/deceased-estate-what-do-i-do-now',
#  'https://www.westpac.com.au/faq/declined-transactions',
#  'https://www.westpac.com.au/faq/delete-online-banking',
#  'https://www.westpac.com.au/faq/digital-card',
#  'https://www.westpac.com.au/faq/digital-card-access',
#  'https://www.westpac.com.au/faq/digital-card-accessibility',
#  'https://www.westpac.com.au/faq/digital-card-additional-cardholder',
#  'https://www.westpac.com.au/faq/digital-card-android',
#  'https://www.westpac.com.au/faq/digital-card-cashless-withdrawal',
#  'https://www.westpac.com.au/faq/digital-card-clipboard-to-copy',
#  'https://www.westpac.com.au/faq/digital-card-compatible-devices',
#  'https://www.westpac.com.au/faq/digital-card-copy-details',
#  'https://www.westpac.com.au/faq/digital-card-eligibilty',
#  'https://www.westpac.com.au/faq/digital-card-expired',
#  'https://www.westpac.com.au/faq/digital-card-funds-access',
#  'https://www.westpac.com.au/faq/digital-card-not-visible',
#  'https://www.westpac.com.au/faq/digital-card-online-transactions',
#  'https://www.westpac.com.au/faq/digital-card-phone-stolen',
#  'https://www.westpac.com.au/faq/digital-card-pin-reset',
#  'https://www.westpac.com.au/faq/digital-card-pin-set',
#  'https://www.westpac.com.au/faq/digital-card-recurring-payments',
#  'https://www.westpac.com.au/faq/digital-card-tablet-ipad-access',
#  'https://www.westpac.com.au/faq/digital-card-use',
#  'https://www.westpac.com.au/faq/digital-card-use-after-reporting-fraud',
#  'https://www.westpac.com.au/faq/digital-card-why-set-pin',
#  'https://www.westpac.com.au/faq/digital-card-with-physical-card',
#  'https://www.westpac.com.au/faq/digital-mail',
#  'https://www.westpac.com.au/faq/digital-mail-all-mail',
#  'https://www.westpac.com.au/faq/digital-mail-availability',
#  'https://www.westpac.com.au/faq/digital-mail-benefits',
#  'https://www.westpac.com.au/faq/digital-mail-change-email',
#  'https://www.westpac.com.au/faq/digital-mail-joint-account',
#  'https://www.westpac.com.au/faq/digital-mail-no-email-notification',
#  'https://www.westpac.com.au/faq/digital-mail-paper',
#  'https://www.westpac.com.au/faq/digital-mail-post',
#  'https://www.westpac.com.au/faq/digital-mail-preferences',
#  'https://www.westpac.com.au/faq/digital-mail-same-as-paper',
#  'https://www.westpac.com.au/faq/digital-mail-save',
#  'https://www.westpac.com.au/faq/digital-mail-security',
#  'https://www.westpac.com.au/faq/digital-mail-switch',
#  'https://www.westpac.com.au/faq/digital-mail-what-is',
#  'https://www.westpac.com.au/faq/digital-mail-where-to-find',
#  'https://www.westpac.com.au/faq/direct-debit-cancel',
#  'https://www.westpac.com.au/faq/direct-debit-cancel-joint-account',
#  'https://www.westpac.com.au/faq/direct-debit-change',
#  'https://www.westpac.com.au/faq/direct-debit-dont-recognise',
#  'https://www.westpac.com.au/faq/direct-debit-how-does-westpac-cancel',
#  'https://www.westpac.com.au/faq/direct-debit-overdraw',
#  'https://www.westpac.com.au/faq/direct-debit-what-is-3-year-block',
#  'https://www.westpac.com.au/faq/direct-debit-what-is-it',
#  'https://www.westpac.com.au/faq/dispute-transaction',
#  'https://www.westpac.com.au/faq/do-i-use-pin-google-pay',
#  'https://www.westpac.com.au/faq/do-i-use-pin-samsung-pay',
#  'https://www.westpac.com.au/faq/does-my-partpay-card-have-a-pin-as-i-am-sometimes-asked-for-one',
#  'https://www.westpac.com.au/faq/does-my-partpay-card-have-the-same-expiry-date-as-my-linked-credit-card',
#  'https://www.westpac.com.au/faq/dont-want-to-use-online-banking',
#  'https://www.westpac.com.au/faq/dt-my-transaction-declined',
#  'https://www.westpac.com.au/faq/eligible-australian-bank-account',
#  'https://www.westpac.com.au/faq/face-id',
#  'https://www.westpac.com.au/faq/face-id-faces-stored',
#  'https://www.westpac.com.au/faq/face-id-how-does-it-work',
#  'https://www.westpac.com.au/faq/face-id-mobile-banking',
#  'https://www.westpac.com.au/faq/face-id-secure',
#  'https://www.westpac.com.au/faq/face-id-sign-in-secure',
#  'https://www.westpac.com.au/faq/face-id-stored',
#  'https://www.westpac.com.au/faq/face-id-unlock-device',
#  'https://www.westpac.com.au/faq/face-id-westpac-app',
#  'https://www.westpac.com.au/faq/face-id-what-is-it',
#  'https://www.westpac.com.au/faq/face-id-what-smartphones',
#  'https://www.westpac.com.au/faq/fatca-legal-obligations',
#  'https://www.westpac.com.au/faq/fileshare',
#  'https://www.westpac.com.au/faq/filter-transactions',
#  'https://www.westpac.com.au/faq/financial-claims-scheme',
#  'https://www.westpac.com.au/faq/financial-hardship',
#  'https://www.westpac.com.au/faq/fitbit-pay',
#  'https://www.westpac.com.au/faq/fitbit-pay-add-cards',
#  'https://www.westpac.com.au/faq/fitbit-pay-card-expired',
#  'https://www.westpac.com.au/faq/fitbit-pay-compatible-devices',
#  'https://www.westpac.com.au/faq/fitbit-pay-device-account-number',
#  'https://www.westpac.com.au/faq/fitbit-pay-eligibility',
#  'https://www.westpac.com.au/faq/fitbit-pay-eligible-cards',
#  'https://www.westpac.com.au/faq/fitbit-pay-factory-reset-impact-card',
#  'https://www.westpac.com.au/faq/fitbit-pay-fitbit-wallet',
#  'https://www.westpac.com.au/faq/fitbit-pay-gift-cards',
#  'https://www.westpac.com.au/faq/fitbit-pay-install',
#  'https://www.westpac.com.au/faq/fitbit-pay-internet-connection',
#  'https://www.westpac.com.au/faq/fitbit-pay-lost-card',
#  'https://www.westpac.com.au/faq/fitbit-pay-lost-stolen',
#  'https://www.westpac.com.au/faq/fitbit-pay-make-payments',
#  'https://www.westpac.com.au/faq/fitbit-pay-more-information',
#  'https://www.westpac.com.au/faq/fitbit-pay-multiple-cards',
#  'https://www.westpac.com.au/faq/fitbit-pay-multiple-devices',
#  'https://www.westpac.com.au/faq/fitbit-pay-overseas',
#  'https://www.westpac.com.au/faq/fitbit-pay-personal-information',
#  'https://www.westpac.com.au/faq/fitbit-pay-phone-nearby',
#  'https://www.westpac.com.au/faq/fitbit-pay-pin',
#  'https://www.westpac.com.au/faq/fitbit-pay-plastic-card',
#  'https://www.westpac.com.au/faq/fitbit-pay-reissued-card',
#  'https://www.westpac.com.au/faq/fitbit-pay-remove-card',
#  'https://www.westpac.com.au/faq/fitbit-pay-rewards',
#  'https://www.westpac.com.au/faq/fitbit-pay-security',
#  'https://www.westpac.com.au/faq/fitbit-pay-sell-device',
#  'https://www.westpac.com.au/faq/fitbit-pay-terms',
#  'https://www.westpac.com.au/faq/fitbit-pay-transaction-declined',
#  'https://www.westpac.com.au/faq/fitbit-pay-verification-needed',
#  'https://www.westpac.com.au/faq/fitbit-pay-view-transactions',
#  'https://www.westpac.com.au/faq/fitbit-pay-what-is-it',
#  'https://www.westpac.com.au/faq/foreign-accounts-tax-compliance-act',
#  'https://www.westpac.com.au/faq/foreign-cash-how-to-order',
#  'https://www.westpac.com.au/faq/forgotten-login',
#  'https://www.westpac.com.au/faq/forgotten-password',
#  'https://www.westpac.com.au/faq/fraud-and-scams',
#  'https://www.westpac.com.au/faq/garmin-pay',
#  'https://www.westpac.com.au/faq/garmin-pay-add-card',
#  'https://www.westpac.com.au/faq/garmin-pay-add-cards',
#  'https://www.westpac.com.au/faq/garmin-pay-apply-terms',
#  'https://www.westpac.com.au/faq/garmin-pay-device-account-number',
#  'https://www.westpac.com.au/faq/garmin-pay-eligible-cards',
#  'https://www.westpac.com.au/faq/garmin-pay-expired-card',
#  'https://www.westpac.com.au/faq/garmin-pay-gift-cards',
#  'https://www.westpac.com.au/faq/garmin-pay-how-does-it-work',
#  'https://www.westpac.com.au/faq/garmin-pay-install',
#  'https://www.westpac.com.au/faq/garmin-pay-internet-connection',
#  'https://www.westpac.com.au/faq/garmin-pay-lost-card',
#  'https://www.westpac.com.au/faq/garmin-pay-make-payment',
#  'https://www.westpac.com.au/faq/garmin-pay-more-information',
#  'https://www.westpac.com.au/faq/garmin-pay-multiple-cards',
#  'https://www.westpac.com.au/faq/garmin-pay-multiple-devices-wallets',
#  'https://www.westpac.com.au/faq/garmin-pay-need-pin',
#  'https://www.westpac.com.au/faq/garmin-pay-new-device',
#  'https://www.westpac.com.au/faq/garmin-pay-overseas',
#  'https://www.westpac.com.au/faq/garmin-pay-personal-information',
#  'https://www.westpac.com.au/faq/garmin-pay-phone-nearby',
#  'https://www.westpac.com.au/faq/garmin-pay-remove-card',
#  'https://www.westpac.com.au/faq/garmin-pay-restore-settings',
#  'https://www.westpac.com.au/faq/garmin-pay-reward-points',
#  'https://www.westpac.com.au/faq/garmin-pay-secure-transaction',
#  'https://www.westpac.com.au/faq/garmin-pay-stolen',
#  'https://www.westpac.com.au/faq/garmin-pay-transaction-decline',
#  'https://www.westpac.com.au/faq/garmin-pay-transaction-limits',
#  'https://www.westpac.com.au/faq/garmin-pay-update-card',
#  'https://www.westpac.com.au/faq/garmin-pay-verification-needed',
#  'https://www.westpac.com.au/faq/garmin-pay-view-transactions',
#  'https://www.westpac.com.au/faq/garmin-pay-wallet',
#  'https://www.westpac.com.au/faq/garmin-pay-which-devices',
#  'https://www.westpac.com.au/faq/general',
#  'https://www.westpac.com.au/faq/handy-card-cvc',
#  'https://www.westpac.com.au/faq/handy-card-how-to-get',
#  'https://www.westpac.com.au/faq/has-westpac-registered-for-fatca',
#  'https://www.westpac.com.au/faq/hey-you-no-cafe-nearby',
#  'https://www.westpac.com.au/faq/hey-you-no-credits',
#  'https://www.westpac.com.au/faq/hey-you-share-details',
#  'https://www.westpac.com.au/faq/hide-accounts',
#  'https://www.westpac.com.au/faq/home-loan-interest-rates',
#  'https://www.westpac.com.au/faq/how-do-i-make-a-pay-anyone-payment',
#  'https://www.westpac.com.au/faq/how-do-i-make-bpay-payment',
#  'https://www.westpac.com.au/faq/how-do-i-make-bpay-payment-online-banking',
#  'https://www.westpac.com.au/faq/how-do-i-register-for-westpac-sms-protect',
#  'https://www.westpac.com.au/faq/how-does-partpay-affect-my-autopay',
#  'https://www.westpac.com.au/faq/how-long-signed-in',
#  'https://www.westpac.com.au/faq/how-much-can-i-send-overseas',
#  'https://www.westpac.com.au/faq/how-to-make-osko-bsb-account-number',
#  'https://www.westpac.com.au/faq/how-to-send-foreign-currency-to-another-australian-bank',
#  'https://www.westpac.com.au/faq/i-ve-just-reported-my-credit-card-lost-stolen-why-is-my-partpay',
#  'https://www.westpac.com.au/faq/iban-number',
#  'https://www.westpac.com.au/faq/identity-check',
#  'https://www.westpac.com.au/faq/if-i-have-no-available-limit-on-my-linked-credit-card-can-i-still-see-partpay-to-make-purchases',
#  'https://www.westpac.com.au/faq/increase-credit-limit',
#  'https://www.westpac.com.au/faq/insights-and-budgeting-add-tag',
#  'https://www.westpac.com.au/faq/insights-and-budgeting-cash-flow',
#  'https://www.westpac.com.au/faq/insights-and-budgeting-cash-flow-account',
#  'https://www.westpac.com.au/faq/insights-and-budgeting-cash-flow-account-removed',
#  'https://www.westpac.com.au/faq/insights-and-budgeting-cash-flow-period',
#  'https://www.westpac.com.au/faq/insights-and-budgeting-categories-data',
#  'https://www.westpac.com.au/faq/insights-and-budgeting-changing-categories',
#  'https://www.westpac.com.au/faq/insights-and-budgeting-closed-accounts-insights',
#  'https://www.westpac.com.au/faq/insights-and-budgeting-creating-tags',
#  'https://www.westpac.com.au/faq/insights-and-budgeting-credit-card-categorised',
#  'https://www.westpac.com.au/faq/insights-and-budgeting-customise-insights',
#  'https://www.westpac.com.au/faq/insights-and-budgeting-delete-tags',
#  'https://www.westpac.com.au/faq/insights-and-budgeting-foreign-currency',
#  'https://www.westpac.com.au/faq/insights-and-budgeting-home-loan-categorised',
#  'https://www.westpac.com.au/faq/insights-and-budgeting-insights-data',
#  'https://www.westpac.com.au/faq/insights-and-budgeting-insights-exclude-account',
#  'https://www.westpac.com.au/faq/insights-and-budgeting-insights-income',
#  'https://www.westpac.com.au/faq/insights-and-budgeting-insights-not-appearing',
#  'https://www.westpac.com.au/faq/insights-and-budgeting-joint-account-tagging',
#  'https://www.westpac.com.au/faq/insights-and-budgeting-joint-categories',
#  'https://www.westpac.com.au/faq/insights-and-budgeting-locate-budgeting-tools',
#  'https://www.westpac.com.au/faq/insights-and-budgeting-positive-expense',
#  'https://www.westpac.com.au/faq/insights-and-budgeting-products-categorised',
#  'https://www.westpac.com.au/faq/insights-and-budgeting-recent-transactions-not-included',
#  'https://www.westpac.com.au/faq/insights-and-budgeting-savings-finder',
#  'https://www.westpac.com.au/faq/insights-and-budgeting-spend-subcategory',
#  'https://www.westpac.com.au/faq/insights-and-budgeting-tags-filtering',
#  'https://www.westpac.com.au/faq/insights-and-budgeting-transaction-categorised',
#  'https://www.westpac.com.au/faq/insights-and-budgeting-transaction-uncategorised',
#  'https://www.westpac.com.au/faq/insights-and-budgeting-transfer-category',
#  'https://www.westpac.com.au/faq/insights-and-budgeting-what-is-a-transaction-tag',
#  'https://www.westpac.com.au/faq/interest-earned',
#  'https://www.westpac.com.au/faq/interest-rates-tax',
#  'https://www.westpac.com.au/faq/intermediary-bank-does-not-convert-transfer',
#  'https://www.westpac.com.au/faq/international-funds-transfer',
#  'https://www.westpac.com.au/faq/international-money-transfer-fees',
#  'https://www.westpac.com.au/faq/international-transfer-rejected',
#  'https://www.westpac.com.au/faq/ipad-how-sign-in-4-digit-passcode',
#  'https://www.westpac.com.au/faq/joint-accounts',
#  'https://www.westpac.com.au/faq/joint-accounts-abandonment',
#  'https://www.westpac.com.au/faq/joint-accounts-access-levels',
#  'https://www.westpac.com.au/faq/joint-accounts-closing-my-account',
#  'https://www.westpac.com.au/faq/joint-accounts-help-opening',
#  'https://www.westpac.com.au/faq/joint-accounts-how-many-can-i-open',
#  'https://www.westpac.com.au/faq/joint-accounts-multiple-accounts',
#  'https://www.westpac.com.au/faq/joint-accounts-opening-with-a-minor',
#  'https://www.westpac.com.au/faq/joint-accounts-protection',
#  'https://www.westpac.com.au/faq/joint-accounts-second-applicant',
#  'https://www.westpac.com.au/faq/joint-accounts-unwanted',
#  'https://www.westpac.com.au/faq/key-changes-accounting-system-payid-osko',
#  'https://www.westpac.com.au/faq/legitimate-or-fake-scam-spam-hoax-email',
#  'https://www.westpac.com.au/faq/letters-calls-SMS',
#  'https://www.westpac.com.au/faq/locate-branch-atm',
#  'https://www.westpac.com.au/faq/lost-stolen-card-online-banking',
#  'https://www.westpac.com.au/faq/lost-stolen-credit-card',
#  'https://www.westpac.com.au/faq/make-a-transfer-or-payment',
#  'https://www.westpac.com.au/faq/manage-limits-online-banking',
#  'https://www.westpac.com.au/faq/manage-pin-change-my-pin',
#  'https://www.westpac.com.au/faq/manage-pin-how-secure',
#  'https://www.westpac.com.au/faq/manage-pin-is-my-card-eligible',
#  'https://www.westpac.com.au/faq/messages-alerts',
#  'https://www.westpac.com.au/faq/migrant-banking',
#  'https://www.westpac.com.au/faq/minimum-amount-term-deposit-managed',
#  'https://www.westpac.com.au/faq/mistake-with-a-term-deposit',
#  'https://www.westpac.com.au/faq/mobile-banking',
#  'https://www.westpac.com.au/faq/mobile-banking-supported-devices',
#  'https://www.westpac.com.au/faq/mobile-download-westpac-app',
#  'https://www.westpac.com.au/faq/mobile-set-up-fingerprint-sign-in-westpac-app',
#  'https://www.westpac.com.au/faq/mobile-use-online-banking-details-westpac-app',
#  'https://www.westpac.com.au/faq/mobile-wallets',
#  'https://www.westpac.com.au/faq/my-merchants',
#  'https://www.westpac.com.au/faq/my-merchants-account-closed',
#  'https://www.westpac.com.au/faq/my-merchants-app-versions',
#  'https://www.westpac.com.au/faq/my-merchants-available-merchants',
#  'https://www.westpac.com.au/faq/my-merchants-card-details-after-connection',
#  'https://www.westpac.com.au/faq/my-merchants-connect-more-than-once',
#  'https://www.westpac.com.au/faq/my-merchants-digital-token-card-details',
#  'https://www.westpac.com.au/faq/my-merchants-eligible-cards',
#  'https://www.westpac.com.au/faq/my-merchants-linked-merchant-transactions-not-showing',
#  'https://www.westpac.com.au/faq/my-merchants-lost-stolen',
#  'https://www.westpac.com.au/faq/my-merchants-new-merchants',
#  'https://www.westpac.com.au/faq/my-merchants-remove-card-details',
#  'https://www.westpac.com.au/faq/my-merchants-remove-token',
#  'https://www.westpac.com.au/faq/my-merchants-secondary-cardholder',
#  'https://www.westpac.com.au/faq/new-biller-payee',
#  'https://www.westpac.com.au/faq/new-credit-card-pin-overseas',
#  'https://www.westpac.com.au/faq/not-a-westpac-customer',
#  'https://www.westpac.com.au/faq/notify-of-overseas-travel',
#  'https://www.westpac.com.au/faq/npp-need-bsb-account',
#  'https://www.westpac.com.au/faq/npp-received-near-real-time-payments',
#  'https://www.westpac.com.au/faq/npp-what-is-it',
#  'https://www.westpac.com.au/faq/npp-what-is-osko',
#  'https://www.westpac.com.au/faq/npp-which-financial-institutions',
#  'https://www.westpac.com.au/faq/on-my-behalf',
#  'https://www.westpac.com.au/faq/online-banking',
#  'https://www.westpac.com.au/faq/online-banking-fees',
#  'https://www.westpac.com.au/faq/online-banking/',
#  'https://www.westpac.com.au/faq/online-form',
#  'https://www.westpac.com.au/faq/open-account-online',
#  'https://www.westpac.com.au/faq/option-to-approve-term-deposit',
#  'https://www.westpac.com.au/faq/osko-payid-change-bank-statement',
#  'https://www.westpac.com.au/faq/partpay',
#  'https://www.westpac.com.au/faq/pay-out-and-close-personal-loan',
#  'https://www.westpac.com.au/faq/pay-to-mobile-payment-accounts',
#  'https://www.westpac.com.au/faq/pay-to-mobile-payment-limits',
#  'https://www.westpac.com.au/faq/pay-to-mobile-secure',
#  'https://www.westpac.com.au/faq/payid-accounts-linked',
#  'https://www.westpac.com.au/faq/payid-another-financial-institution',
#  'https://www.westpac.com.au/faq/payid-bsb-account-number',
#  'https://www.westpac.com.au/faq/payid-created-automatically',
#  'https://www.westpac.com.au/faq/payid-display-name',
#  'https://www.westpac.com.au/faq/payid-donot-want-upgrade',
#  'https://www.westpac.com.au/faq/payid-dont-have-sms-protect',
#  'https://www.westpac.com.au/faq/payid-eligible-busi-acc',
#  'https://www.westpac.com.au/faq/payid-eligible-business-accounts',
#  'https://www.westpac.com.au/faq/payid-eligible-corporate-accounts',
#  'https://www.westpac.com.au/faq/payid-eligible-personal-accounts',
#  'https://www.westpac.com.au/faq/payid-get-ready',
#  'https://www.westpac.com.au/faq/payid-how-to-create',
#  'https://www.westpac.com.au/faq/payid-link-accounts-how-many',
#  'https://www.westpac.com.au/faq/payid-lock-payid',
#  'https://www.westpac.com.au/faq/payid-make-payments',
#  'https://www.westpac.com.au/faq/payid-mobile-number-change',
#  'https://www.westpac.com.au/faq/payid-only-option',
#  'https://www.westpac.com.au/faq/payid-osko',
#  'https://www.westpac.com.au/faq/payid-osko-difference-pay-to-mobile',
#  'https://www.westpac.com.au/faq/payid-osko-fees',
#  'https://www.westpac.com.au/faq/payid-osko-international-money-transfer',
#  'https://www.westpac.com.au/faq/payid-osko-what-is-it',
#  'https://www.westpac.com.au/faq/payid-payment-received',
#  'https://www.westpac.com.au/faq/payid-receive-payments',
#  'https://www.westpac.com.au/faq/payid-safe-and-secure',
#  'https://www.westpac.com.au/faq/payid-transaction-limit-osko',
#  'https://www.westpac.com.au/faq/payid-transfer-payid',
#  'https://www.westpac.com.au/faq/payid-verify-payee',
#  'https://www.westpac.com.au/faq/payid-what-can-i-use',
#  'https://www.westpac.com.au/faq/payid-what-is-it',
#  'https://www.westpac.com.au/faq/payid-who-can-i-pay',
#  'https://www.westpac.com.au/faq/payment-options',
#  'https://www.westpac.com.au/faq/payto-agreement-changes',
#  'https://www.westpac.com.au/faq/payto-banking',
#  'https://www.westpac.com.au/faq/payto-customers',
#  'https://www.westpac.com.au/faq/payto-eligible-accounts',
#  'https://www.westpac.com.au/faq/payto-email-action',
#  'https://www.westpac.com.au/faq/payto-link-with-payid',
#  'https://www.westpac.com.au/faq/payto-making-payments',
#  'https://www.westpac.com.au/faq/payto-not-eligible',
#  'https://www.westpac.com.au/faq/payto-pause-or-cancel',
#  'https://www.westpac.com.au/faq/payto-ready',
#  'https://www.westpac.com.au/faq/payto-see-upcoming-payments',
#  'https://www.westpac.com.au/faq/payto-signatory-authorisation',
#  'https://www.westpac.com.au/faq/payto-transaction-limit',
#  'https://www.westpac.com.au/faq/payto-unsuccessful-payment',
#  'https://www.westpac.com.au/faq/payto-vs-direct-debit',
#  'https://www.westpac.com.au/faq/pending-balance',
#  'https://www.westpac.com.au/faq/pending-refund',
#  'https://www.westpac.com.au/faq/pending-transactions',
#  'https://www.westpac.com.au/faq/permissions-android-mobile-banking',
#  'https://www.westpac.com.au/faq/permissions-iphone-mobile-banking',
#  'https://www.westpac.com.au/faq/personal-customer-how-to-activate-a-token',
#  'https://www.westpac.com.au/faq/personal-customer-how-to-order-replacement-token',
#  'https://www.westpac.com.au/faq/personalise-app',
#  'https://www.westpac.com.au/faq/protect-myself-from-online-banking-fraud',
#  'https://www.westpac.com.au/faq/pt-balance-affected',
#  'https://www.westpac.com.au/faq/pt-cancel-pending-transaction',
#  'https://www.westpac.com.au/faq/pt-dont-recognise',
#  'https://www.westpac.com.au/faq/pt-what-is-pending-transaction',
#  'https://www.westpac.com.au/faq/purpose-reference-id-osko',
#  'https://www.westpac.com.au/faq/push-notifications',
#  'https://www.westpac.com.au/faq/quick-balance-accounts',
#  'https://www.westpac.com.au/faq/quick-balance-change-displayed-accounts',
#  'https://www.westpac.com.au/faq/quick-balance-remove',
#  'https://www.westpac.com.au/faq/quick-balance-security',
#  'https://www.westpac.com.au/faq/quick-balance-set-up',
#  'https://www.westpac.com.au/faq/quick-balance-too-many-registrations',
#  'https://www.westpac.com.au/faq/quick-transfer',
#  'https://www.westpac.com.au/faq/real-time-payment-npp',
#  'https://www.westpac.com.au/faq/real-westpac-website',
#  'https://www.westpac.com.au/faq/reason-for-payment',
#  'https://www.westpac.com.au/faq/receive-assistance',
#  'https://www.westpac.com.au/faq/received-hoax-spam-scam-fake-email',
#  'https://www.westpac.com.au/faq/received-sms-code-didnt-make-transaction',
#  'https://www.westpac.com.au/faq/receiving-support-and-account-is-overdrawn',
#  'https://www.westpac.com.au/faq/recurring-payments',
#  'https://www.westpac.com.au/faq/replacement-for-expiring-expired-token',
#  'https://www.westpac.com.au/faq/restrictions-for-making-changes',
#  'https://www.westpac.com.au/faq/results',
#  'https://www.westpac.com.au/faq/running-balances',
#  'https://www.westpac.com.au/faq/samsung-pay',
#  'https://www.westpac.com.au/faq/samsung-pay-add-card',
#  'https://www.westpac.com.au/faq/samsung-pay-declined-transaction',
#  'https://www.westpac.com.au/faq/samsung-pay-digital-card-number',
#  'https://www.westpac.com.au/faq/samsung-pay-eftpos-difference',
#  'https://www.westpac.com.au/faq/samsung-pay-eligible-cards',
#  'https://www.westpac.com.au/faq/samsung-pay-expired-card',
#  'https://www.westpac.com.au/faq/samsung-pay-internet-connection',
#  'https://www.westpac.com.au/faq/samsung-pay-lose-card',
#  'https://www.westpac.com.au/faq/samsung-pay-lost-stolen',
#  'https://www.westpac.com.au/faq/samsung-pay-mastercard',
#  'https://www.westpac.com.au/faq/samsung-pay-mastercard-eftpos',
#  'https://www.westpac.com.au/faq/samsung-pay-more-information',
#  'https://www.westpac.com.au/faq/samsung-pay-new-phone',
#  'https://www.westpac.com.au/faq/samsung-pay-personal-information',
#  'https://www.westpac.com.au/faq/samsung-pay-reissued-card',
#  'https://www.westpac.com.au/faq/samsung-pay-remove-suspend-card',
#  'https://www.westpac.com.au/faq/samsung-pay-samsung-gear',
#  'https://www.westpac.com.au/faq/samsung-pay-samsung-gear-remove',
#  'https://www.westpac.com.au/faq/samsung-pay-samsung-gear-watch',
#  'https://www.westpac.com.au/faq/samsung-pay-security',
#  'https://www.westpac.com.au/faq/samsung-pay-transaction-limits',
#  'https://www.westpac.com.au/faq/samsung-pay-verify-card',
#  'https://www.westpac.com.au/faq/samsung-pay-what-is-it',
#  'https://www.westpac.com.au/faq/samsung-pay-which-phones',
#  'https://www.westpac.com.au/faq/security',
#  'https://www.westpac.com.au/faq/security-devices',
#  'https://www.westpac.com.au/faq/set-up-australian-bank-account',
#  'https://www.westpac.com.au/faq/sign-out-close-browser',
#  'https://www.westpac.com.au/faq/six-business-day-period',
#  'https://www.westpac.com.au/faq/smartplan-activate',
#  'https://www.westpac.com.au/faq/smartplan-affect-my-credit-card-payments',
#  'https://www.westpac.com.au/faq/smartplan-benefits',
#  'https://www.westpac.com.au/faq/smartplan-cancellation',
#  'https://www.westpac.com.au/faq/smartplan-card-autopay',
#  'https://www.westpac.com.au/faq/smartplan-changes-to-statement',
#  'https://www.westpac.com.au/faq/smartplan-cost',
#  'https://www.westpac.com.au/faq/smartplan-credit-card-limit',
#  'https://www.westpac.com.au/faq/smartplan-credit-checks',
#  'https://www.westpac.com.au/faq/smartplan-eligible-amounts',
#  'https://www.westpac.com.au/faq/smartplan-estimated-total-repayment',
#  'https://www.westpac.com.au/faq/smartplan-extra-repayments',
#  'https://www.westpac.com.au/faq/smartplan-how-many',
#  'https://www.westpac.com.au/faq/smartplan-how-to-balance-transfer',
#  'https://www.westpac.com.au/faq/smartplan-how-to-calculate-monthly-repayment',
#  'https://www.westpac.com.au/faq/smartplan-how-to-cash-advance',
#  'https://www.westpac.com.au/faq/smartplan-how-to-purchase-balance',
#  'https://www.westpac.com.au/faq/smartplan-interest-free-days-benefit',
#  'https://www.westpac.com.au/faq/smartplan-main-account-balance',
#  'https://www.westpac.com.au/faq/smartplan-miss-repayment',
#  'https://www.westpac.com.au/faq/smartplan-monthly-payment-balance',
#  'https://www.westpac.com.au/faq/smartplan-monthly-payment-due',
#  'https://www.westpac.com.au/faq/smartplan-view-my-repayments',
#  'https://www.westpac.com.au/faq/smartplan-what-is-it',
#  'https://www.westpac.com.au/faq/smartplan-who-can-set-up',
#  'https://www.westpac.com.au/faq/spend-and-save-faqs',
#  'https://www.westpac.com.au/faq/spend-insights-and-budgeting-tools',
#  'https://www.westpac.com.au/faq/statement-copy-online',
#  'https://www.westpac.com.au/faq/status-replacement-credit-card',
#  'https://www.westpac.com.au/faq/supporting-documents',
#  'https://www.westpac.com.au/faq/swift-codes',
#  'https://www.westpac.com.au/faq/tablet-banking',
#  'https://www.westpac.com.au/faq/tablet-fingerprint-authentication',
#  'https://www.westpac.com.au/faq/tablet-fingerprint-disable',
#  'https://www.westpac.com.au/faq/tablet-fingerprint-how',
#  'https://www.westpac.com.au/faq/tablet-fingerprint-incorrect',
#  'https://www.westpac.com.au/faq/tablet-fingerprint-ipad-unlock',
#  'https://www.westpac.com.au/faq/tablet-fingerprint-multiple-devices',
#  'https://www.westpac.com.au/faq/tablet-fingerprint-multiple-fingerprints',
#  'https://www.westpac.com.au/faq/tablet-fingerprint-security',
#  'https://www.westpac.com.au/faq/tablet-fingerprint-sign-in-security',
#  'https://www.westpac.com.au/faq/tablet-fingerprint-stolen-device',
#  'https://www.westpac.com.au/faq/tablet-incorrect-password-entered',
#  'https://www.westpac.com.au/faq/tablet-overseas-protection',
#  'https://www.westpac.com.au/faq/tablet-security',
#  'https://www.westpac.com.au/faq/tablet-security-sms-code',
#  'https://www.westpac.com.au/faq/tablet-setup-same-passcode',
#  'https://www.westpac.com.au/faq/tablet-sign-out',
#  'https://www.westpac.com.au/faq/tablet-stolen',
#  'https://www.westpac.com.au/faq/tap-and-pay-removed',
#  'https://www.westpac.com.au/faq/term-deposit-security-restricted',
#  'https://www.westpac.com.au/faq/third-party-account-access',
#  'https://www.westpac.com.au/faq/transaction-search',
#  'https://www.westpac.com.au/faq/transfer-funds-overseas',
#  'https://www.westpac.com.au/faq/transferring-between-accounts-online',
#  'https://www.westpac.com.au/faq/transferring-funds',
#  'https://www.westpac.com.au/faq/travelling-overseas',
#  'https://www.westpac.com.au/faq/trusted_wifi',
#  'https://www.westpac.com.au/faq/type-of-assistance',
#  'https://www.westpac.com.au/faq/unhappy-with-response',
#  'https://www.westpac.com.au/faq/upcoming-payments',
#  'https://www.westpac.com.au/faq/us-citizen-or-tax-resident',
#  'https://www.westpac.com.au/faq/verify-identity',
#  'https://www.westpac.com.au/faq/view-closed-account-statements',
#  'https://www.westpac.com.au/faq/ways-to-pay-credit-card',
#  'https://www.westpac.com.au/faq/westpac-online-banking-doesnt-look-right',
#  'https://www.westpac.com.au/faq/westpac-online-banking-updates',
#  'https://www.westpac.com.au/faq/westpac-protect-extra-protection',
#  'https://www.westpac.com.au/faq/westpac-protect-sms-code-looks-different',
#  'https://www.westpac.com.au/faq/westpac-swift-code',
#  'https://www.westpac.com.au/faq/what-can-third-party-account-access',
#  'https://www.westpac.com.au/faq/what-happens-after-international-money-transfer',
#  'https://www.westpac.com.au/faq/what-happens-if-my-partpay-autopay-is-dishonoured',
#  'https://www.westpac.com.au/faq/what-happens-when-i-get-a-refund-on-a-partpay-purchase',
#  'https://www.westpac.com.au/faq/what-if-having-issues-creating-a-payid',
#  'https://www.westpac.com.au/faq/what-is-exchange-rate-for-recurring-international-money-transfers',
#  'https://www.westpac.com.au/faq/what-transactions',
#  'https://www.westpac.com.au/faq/when-able-receive-osko',
#  'https://www.westpac.com.au/faq/when-can-i-use-term-deposit-online-banking',
#  'https://www.westpac.com.au/faq/where-can-i-see-my-upcoming-partpay-payments-and-previously-made-payments',
#  'https://www.westpac.com.au/faq/who-are-westpacs-correspondent-banks',
#  'https://www.westpac.com.au/faq/why-did-I-not-receive-full-amount-overseas-payee-sent-me',
#  'https://www.westpac.com.au/faq/why-did-the-overseas-beneficiary-not-receive-full-amount',
#  'https://www.westpac.com.au/faq/why-email-address',
#  'https://www.westpac.com.au/faq/worldwide-wallet',
#  'https://www.westpac.com.au/faq/worldwide-wallet-activation',
#  'https://www.westpac.com.au/faq/worldwide-wallet-assistance',
#  'https://www.westpac.com.au/faq/worldwide-wallet-can-anyone-apply',
#  'https://www.westpac.com.au/faq/worldwide-wallet-card-renewal',
#  'https://www.westpac.com.au/faq/worldwide-wallet-close-account',
#  'https://www.westpac.com.au/faq/worldwide-wallet-converting-currencies',
#  'https://www.westpac.com.au/faq/worldwide-wallet-dispute-transaction',
#  'https://www.westpac.com.au/faq/worldwide-wallet-flight-delay-pass',
#  'https://www.westpac.com.au/faq/worldwide-wallet-is-it-a-credit-card',
#  'https://www.westpac.com.au/faq/worldwide-wallet-load-or-reload-money',
#  'https://www.westpac.com.au/faq/worldwide-wallet-lost-stolen',
#  'https://www.westpac.com.au/faq/worldwide-wallet-mastercard-flight-delay-pass',
#  'https://www.westpac.com.au/faq/worldwide-wallet-on-apple-pay',
#  'https://www.westpac.com.au/faq/worldwide-wallet-overseas-atms',
#  'https://www.westpac.com.au/faq/worldwide-wallet-overseas-travel',
#  'https://www.westpac.com.au/faq/worldwide-wallet-pin',
#  'https://www.westpac.com.au/faq/worldwide-wallet-remaining-money',
#  'https://www.westpac.com.au/faq/worldwide-wallet-shopping-online-in-foreign-currencies',
#  'https://www.westpac.com.au/faq/worldwide-wallet-spend-in-a-currency-not-loaded-on-my-account',
#  'https://www.westpac.com.au/faq/worldwide-wallet-spend-in-a-currency-not-offered',
#  'https://www.westpac.com.au/faq/worldwide-wallet-statements',
#  'https://www.westpac.com.au/faq/worldwide-wallet-tap-and-go',
#  'https://www.westpac.com.au/faq/worldwide-wallet-transaction-time-zone',
#  'https://www.westpac.com.au/faq/worldwide-wallet-transfer-foreign-currencies',
#  'https://www.westpac.com.au/faq/worldwide-wallet-travelling-in-less-than-8-days',
#  'https://www.westpac.com.au/faq/worldwide-wallet-westpac-app',
#  'https://www.westpac.com.au/faq/worldwide-wallet-what-are-pending-transactions',
#  'https://www.westpac.com.au/faq/worldwide-wallet-what-is-emergency-cash',
#  'https://www.westpac.com.au/faq/worldwide-wallet-will-i-be-charged-if-i-use-an-atm',
#  'https://www.westpac.com.au/faq/your-home-loan-interest-rate',
#  'https://www.westpac.com.au/help',
#  'https://www.westpac.com.au/help/',
#  'https://www.westpac.com.au/help/community',
#  'https://www.westpac.com.au/help/contact-us',
#  'https://www.westpac.com.au/help/difficult-circumstances',
#  'https://www.westpac.com.au/help/disaster-help',
#  'https://www.westpac.com.au/help/faq',
#  'https://www.westpac.com.au/help/indigenous-banking',
#  'https://www.westpac.com.au/help/lifemoments',
#  'https://www.westpac.com.au/help/locate-us',
#  'https://www.westpac.com.au/help/lost-stolen-card',
#  'https://www.westpac.com.au/help/master-your-money',
#  'https://www.westpac.com.au/help/security',
#  'https://www.westpac.com.au/help/ways-to-bank',
#  'https://www.westpac.com.au/help/ways-to-bank/',
#  'https://www.westpac.com.au/help/ways-to-bank/co-located-branches',
#  'https://www.westpac.com.au/locateus',
#  'https://www.westpac.com.au/locateus/',
#  'https://www.westpac.com.au/personal-banking',
#  'https://www.westpac.com.au/personal-banking/bank-accounts',
#  'https://www.westpac.com.au/personal-banking/bank-accounts/cancel-direct-debit',
#  'https://www.westpac.com.au/personal-banking/credit-cards',
#  'https://www.westpac.com.au/personal-banking/home-loans',
#  'https://www.westpac.com.au/personal-banking/insurance',
#  'https://www.westpac.com.au/personal-banking/investments',
#  'https://www.westpac.com.au/personal-banking/mobile-wallets',
#  'https://www.westpac.com.au/personal-banking/mobile-wallets/digital-card/',
#  'https://www.westpac.com.au/personal-banking/online-banking',
#  'https://www.westpac.com.au/personal-banking/online-banking/features',
#  'https://www.westpac.com.au/personal-banking/online-banking/making-the-most/activate-your-card',
#  'https://www.westpac.com.au/personal-banking/online-banking/making-the-most/lost-stolen-card',
#  'https://www.westpac.com.au/personal-banking/online-banking/making-the-most/lost-stolen-card/',
#  'https://www.westpac.com.au/personal-banking/online-banking/making-the-most/manage-term-deposit',
#  'https://www.westpac.com.au/personal-banking/online-banking/making-the-most/payments-transfers',
#  'https://www.westpac.com.au/personal-banking/online-banking/making-the-most/quick-balance',
#  'https://www.westpac.com.au/personal-banking/online-banking/making-the-most/smart-search',
#  'https://www.westpac.com.au/personal-banking/online-banking/making-the-most/update-details',
#  'https://www.westpac.com.au/personal-banking/online-banking/ways-to-bank/mobile-banking',
#  'https://www.westpac.com.au/personal-banking/personal-loans',
#  'https://www.westpac.com.au/personal-banking/private-banking-services',
#  'https://www.westpac.com.au/personal-banking/services',
#  'https://www.westpac.com.au/personal-banking/services/atms/atm-features',
#  'https://www.westpac.com.au/personal-banking/share-trading',
#  'https://www.westpac.com.au/personal-banking/superannuation',
#  'https://www.westpac.com.au/personal-banking/travel-centre',
#  'https://www.westpac.com.au/security/fraud-and-scams/reporting-scams',
#  'https://www.westpac.com.au/web-accessibility']

# %%
from langchain.document_loaders import WebBaseLoader
import re

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.0.0 Safari/537.36"
}

print("Loading Data")
url_loaders = WebBaseLoader(urls, header_template=headers)
data = url_loaders.load()

"""
Extract only the actual Article content from the web page and clean
"""
print("Cleaning Data")
for i, d in enumerate(data):
    d.page_content = ""
    source = d.metadata['source']
    thedoc = WebBaseLoader(source, header_template=headers).scrape()
    # extract only the Content Div from the web page
    td = thedoc.find('div', class_='content').text
    d.page_content = clean_text(td)
    data[i] = d

print (f"Number of documents: {len(urls)}")
print (f"Number of tokens: {num_tokens_from_string(data[0].page_content)}")
# Out:
# Loading Data
# Cleaning Data
# Number of documents: 825
# Number of tokens: 461

# %% [markdown]
# #### Split the data into chunks

# %%
from langchain.text_splitter import TokenTextSplitter

CHUNK_SIZE = 500

# Chunk the data
print("Splitting Data")
text_splitter = TokenTextSplitter(chunk_size=CHUNK_SIZE, chunk_overlap=50)
docs = text_splitter.split_documents(data)
print(f"Number of chunks: {len(docs)}")
# Out:
# Splitting Data
# Number of chunks: 1158

# %% [markdown]
# ## Create the Vector Store
#
# #### Astra DB Connectivity

# %%
import os
from dotenv import load_dotenv

load_dotenv()

ASTRA_DB_APPLICATION_TOKEN = os.environ["ASTRA_DB_APPLICATION_TOKEN"]
ASTRA_VECTOR_ENDPOINT = os.environ["ASTRA_VECTOR_ENDPOINT"]
ASTRA_DB_KEYSPACE = os.environ["ASTRA_DB_KEYSPACE"]
ASTRA_DB_COLLECTION = os.environ["ASTRA_DB_COLLECTION"]
OPENAI_API_KEY = os.environ["OPENAI_API_KEY"]

# %% [markdown]
# #### Define the Vector Store

# %%
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores.astradb import AstraDB


# define Embedding model
embeddings = OpenAIEmbeddings()

# Set up the vector store
print("Setup Vector Store")
vectorstore = AstraDB(
    embedding=embeddings,
    namespace=ASTRA_DB_KEYSPACE,
    collection_name=ASTRA_DB_COLLECTION,
    token=ASTRA_DB_APPLICATION_TOKEN,
    api_endpoint=ASTRA_VECTOR_ENDPOINT,
)
# Out:
# Setup Vector Store

# %% [markdown]
# ## Store data and embeddings in Astra DB

# %%
print("Adding texts to Vector Store")
texts, metadatas = zip(*((doc.page_content, doc.metadata) for doc in docs))
vectorstore.add_texts(texts=texts, metadatas=metadatas)
# Out:
# Adding texts to Vector Store
# ['e0c9e4af20ec41ca89453879ff32ed3d',
#  'a66c86501e764a9b8a2f527d751ed10e',
#  '45fb35359fc642eea5ab8be52b89d465',
#  '3b2b35f3d9bc45dc98f8d65b7b422afc',
#  'c6c136489cb548d2ad06df15ef6a07e9',
#  'a8882e9d600f4a6e8b6b9498b194d1c7',
#  '28d2fbe032054b5fba5cb083a3a668ae',
#  'e9854e72df4349faa512d4a2996654f2',
#  '1c28912670d54f47acea52f51a15467a',
#  '2437ee5f049b4c9ab4a25e261750ab58',
#  'f9c4aa7e0c624162809c806ceb4f08c0',
#  '6f3be05a01b9447ebeb129b410bffa76',
#  '5635bf6c86ab489c86b3ba9e863e14a9',
#  '02664570b7c042a297d4e5e8028195b0',
#  '60ad16c6deb342e193b8a9eb1871dcbf',
#  '4cbdaaaa9cea4a51b08ea50a3aa310d7',
#  'de7bf721e3cb406189d2292203db2466',
#  'd1c77b6336fd4ef28e6a89a5f68cc7d4',
#  'de56c0408ce74a6fa0f123f5d59833b3',
#  '8565bf6566c14ffca4794b6692de88bb',
#  '5f78a3261ad34a4b8a250be721340867',
#  '080bd1b4c69145bd9bd2f46b741822c6',
#  '0ee817dfb0a84b46bf3e4a59f65ebd9d',
#  '53f3f72bcee84d0e82938bcc5550b1dc',
#  'f0eed058d5db4e74bb209b9b76e5c9c6',
#  '1870a11f45be491a985d2c7adf621374',
#  '710185de0e99481691dd2defe171050f',
#  'bf98050a6c6143358193265f4075713c',
#  '993872f47e96492b9508b67e10da69b7',
#  'ca1bf3077e4f47cfb28ab0437d3c6619',
#  '0d1e613e75944ef18020586ecf5ce150',
#  '025ab7c8f418414d86f1c8f93cdb4a19',
#  '2699902aa0be4bee91f17f8f745e5702',
#  'e36d090153604cb38e42263c75a61a47',
#  'ace394936002420e8aedd4b5f8a2982d',
#  'e4fe056d05a54f7496af2130f9e89e0c',
#  '978b43e59bf54c5f86f38ce601ff31c9',
#  'c5b8a80925a94731915a8433c4770c61',
#  '01b61d6d2dbe4e8aabb7f47576761e1a',
#  'c5fbc380e0ae4395824dff280abc0093',
#  '6656ad5e6c11458ea2243cf097d248dc',
#  '3e7511343858445286e498385abc47a3',
#  '38f240b0527b4acaab14efd808dd5e36',
#  '5f20692a530744e8a7fad570d03cb410',
#  '1ba01ba6ccd64007a1e96f0f89c795eb',
#  'f2755e580127497b8b75c35fa4aa463f',
#  '2952eff293d9453e89de886eeed7ce30',
#  '0175b8ba1bda4c6a8401ff97bd23dda5',
#  'b43396308302487893f846e54ee5aa04',
#  'ce92bff21cab4fc7aaad9a3fd85bca79',
#  '7d75ab3e407543fcb04d940439b6329a',
#  '88ee8de5fbfc47408c8913fa78af1c28',
#  '20188eef98334f97a9806f8874972f97',
#  'd37682961e39464d98ee32a38b1c22ed',
#  'd3602339e8a846a4ae49235ff48a7056',
#  '4c9ecf1f59b34097aeef3425dc500bc1',
#  'caf96f938a064bd89231cb28ea2fdc52',
#  'f44c45a870ef436c8c8183de2b3a7d18',
#  'd6a7878e43d64741ab781d2394d805c4',
#  '47a71a1d06964f43ba7d06fca89855d4',
#  'c9197c6583d9461b9e2a69f0c4495253',
#  '5e3ac848c7b74ca4971beb2da1cc6bd5',
#  '455132c710ae4556966b6dbc0b59af02',
#  '8c071f79a3244c09b5a71eca7ee27537',
#  'f68852b7c9c742feb036c9d8cd1542b6',
#  '8ed3d9cb25e648bd92826b50f4f08b1d',
#  '9838df78295d426f83c22996ec11bd28',
#  '3401347b78b449649788d7b28398aadf',
#  'a6180fd4bf2a47ac967738c016b57d07',
#  '99fee378c512442ebca1caeb2911172f',
#  'b083f76c523c49eaad5c181649513fc5',
#  '3805b60af2ed4deda00ce579bef65e83',
#  'dcba74cb50054eabb4011a49b3c96229',
#  '4bbad787d9c944d99fa8492d681c9e48',
#  '9235a70374a0421088ff98944b7f2744',
#  'da1d74ae37c947ca8794932cc573d2d4',
#  '2c64bf037cbf42628f789dc1440e05b3',
#  '2948147837ce41e69daf1f3435b1eb74',
#  '0666ee8a6baf41adb51fe57ba25db885',
#  '3cc55934337d491598ab6f35e57d05e3',
#  'b4f58f4c6fb64eb18554d9045ea51431',
#  '913d0757bdb14fac82489457b7475333',
#  '027e1c8d831e46d3a7762440a69cc0fa',
#  '4894b29198e142b6af36d7db7d4bd1e3',
#  'b868abfa6c774796b4effa8019ea33a0',
#  '8a060710ece247eba53f25f9d1f8a61f',
#  '0d8e75bb47a34b259c46f1b2149adbdc',
#  'bb45a6ba575f46a999bbe4db424af885',
#  'b9c55cdf681c4d7c9a54d04c173dbd39',
#  '3d7a0e0ecd45431498f4c45d9e6fb079',
#  '58eacf8590054b0489f8c2f43289def1',
#  'b9e86975883944038e3679e9e2969d4e',
#  '4571a4a42b1e4bc68fe4bb90cfc91d2e',
#  '39f683d1413f4f7cbf9cc3b30a17a6cf',
#  '3babb9029cc64b08926db1980acdb3e9',
#  '29627157223b40f4a84aadda4f23eacf',
#  '1ac7a125d85a4116bb26607d53815f42',
#  'f1af8501b2ee48699aea59a60966ecff',
#  'fefede2022e9424dbaa8475e1460f8a9',
#  '4679fa8038204174b991afcf6582db83',
#  '74905758c0e74a4980047cb1bdba6f93',
#  'f12083ba421644d2a8c14bcdb6a4683e',
#  'cb41c79518324cafb082dab8e278001f',
#  '4f30fb3dcdac49ebae336fef88d735cc',
#  'b22bf490d6eb49548976f817f530fda4',
#  'f0642a9aacbf4110b937106964ab1e45',
#  'd5d774e4aaca4fe1b62beae23d466e07',
#  '438301ff885b4d5e902a5a0a7b4c4235',
#  '6890500d2382490aae2c15149bf16165',
#  '3a09c1b70d46443b998d780fe77be56e',
#  'c3fb504b01054a32ba30fc44c57c0af0',
#  'af64d54d6583484a9238ed541adef0ab',
#  'deb392f185e049fb8ba3ceba803b2b73',
#  '8ea60499580e4075a6004a2c5b080513',
#  'c108331e68e34b2b8fc3ea9fb06d559f',
#  'c080cabcf0cd480f86035931b8636fb3',
#  'b192a0c97ef64d728be4c63e81dfe186',
#  '0a29d48663584c4085ad4e59bd7c1c85',
#  '8ae1440a1443474a83182089c00042d5',
#  '9ed9fb38fa3141f5a79f2d369093a8ad',
#  'c0b8b58a955a48378e9977b527925b25',
#  'aab3732f7cab45caba8e5fccac66e61b',
#  '22ab2ab730db4347bc74295247cfe8d6',
#  'dc4240f243e446db86971497d9a572e7',
#  '441f91f9eebf48a9a30abfcef59793fe',
#  'c60b73b4b9eb49cda5e6f9ec1a8e6e71',
#  'ba3d1eca82a84903a93f23de3cb90661',
#  '145aeb07597a4773958e8ce740935cfb',
#  '2bd0facd8a6c45959a8b54347a083572',
#  '81ff3cff192e41a68f95d9acc94b4739',
#  '2f2bd634b3854d32a3c5e886698e5ab8',
#  '235c22bf7d884454a48962aa3f5b621c',
#  '1177bac2d10646448124c9dc6e7dec13',
#  '82b81ff8f6c44387933367ed3eaaa46f',
#  '15c9d4910b4346b4b568515c08dc06f9',
#  'acec592301c54bd6a78fb0633671b2a9',
#  '399c51dd55814ffbb8c311299f92ba50',
#  '01e2536e7c9045bfbd5aa5517ff9dac6',
#  '5ce2120f8c9e4f9dadfe3987a2e46e2a',
#  'cceeef6312a44dc3baf3f439775754f1',
#  '426a763959a54b3e982602db3854b190',
#  'e24d4a35a337421fad7b7c04126febb5',
#  'a2bbb42572ea4c039c2c32004f5f3838',
#  '8e5803f88050410883fd93bd88a00064',
#  '32eec76bbcb04f5eb398f95d3aa8cc2c',
#  'c6a2e5e49a464d1b8bff95e983910e83',
#  '803ecba961954abaa6c269c8382cf087',
#  '51922f77739b491f9bb8cef2ca4c9b61',
#  'ffaa97970b884261ab92042bbb430861',
#  '3af4081af25c4a3c93f75eb3b6081b54',
#  '8ab86ca7934a4117ac6806430f233ea1',
#  '63748892b0cc4aaa857e07f9e198ef08',
#  'f77e2b9a42bd4f55b2af53d998558cbd',
#  'b48c06d4c68d468682c4afd3583570ab',
#  'dbb16a3ed57a4d2e9db3829df48ebc35',
#  'e327cafcd7ff4921b64c6c52c6805bc1',
#  '8b502e47f85f4d4cacc8b80777aedc98',
#  '2207d4836ab642e4b6a2b3e5a8d966d5',
#  'c37f8a30e62a4bb59885da47a6f05a9d',
#  '8ae1ca9d78924d1193d5fb61d7dcf295',
#  'd8af3cd60e554ab1b3365abda1f05d49',
#  'af710fd6a5844187a47fd7f64716a8dc',
#  '8cadbf06f36a40769aef2d957130da07',
#  '61304e40f23043559631a7d7f5393725',
#  'd9c4251183c64db1b66ad2fc14d46b7f',
#  '2834247db106434fa5dcaa5852bf530a',
#  '33fe43db1187433abb59381871693472',
#  '9a4605dff1ae46aea14cf00aec659ac0',
#  'e2056cd7f38940e4bb7483260a7225fb',
#  'f367d4e235834e3eb51d12a101754753',
#  '8f5a94bfc5624dff9541182e23fd209d',
#  'fa24c7fe4955403b911821d9d4e27917',
#  'a0c5133827a2468dac711932939c557e',
#  'df1cee0afdb84ebc969628b545880ba2',
#  'a7cd146986bf4897a47c4674f12c043e',
#  '4d8880ec5b7642e8b12e8145d4eff953',
#  'b8f153e9ff1a4db1b289649fb1c159a8',
#  'b92a772c89de42ddb1fd656119d68d02',
#  '3112530f803b4fd7bfb704a55ea1d3b2',
#  'ba38e7c3216445fe9fc581745bba016b',
#  '3bacbcb5f8ec48c0b6fd0c1a50dfa7b2',
#  '42e4a502a697460c8cc5f4b297d509f0',
#  'b766f9d0f3b945659849830cd477ddf6',
#  '573d1c9899f84d1a82908a96391d8d7f',
#  '3333f5591daa4f09b7378ef2b6535001',
#  '980c4b9bc5494b62a1324dec90f1ed0f',
#  '5fd93dfc3f2b493b9ed74415929d0d5b',
#  '6ec908e067a2434a869b9f050e80b274',
#  'f68bebf974f4486abc7f9e35342fd04d',
#  'd672b8b341df412986566296ac481f3f',
#  'e92831f934f9427ebaed86e29cca1947',
#  '630665a5edb2443ead3d38bc4667a079',
#  '4d9bf901c4f94f49892a18899e9664b1',
#  '4964dd6ce4e34a52bad7f6a3388fe71b',
#  '7cbebdbf3bbd433d853f3dcbfbeda8fd',
#  'ad2cd91b704a46559ebfe46dd684c64b',
#  '066e4975ad804db282bbc36739c0b010',
#  '923150dc9997421baa5ba8ef788e3b90',
#  '9c663af9fb99480089f42460f9a9ff8e',
#  '7a3668e41a5f4143ae32cc363ee43533',
#  '578eb92091c54836a548cb258643c481',
#  'fbc4787f78bb4f5297489f00bd655d21',
#  '46cc9c64b6d64c6494d799e1802f9a64',
#  '70538ac6cdac4e65b31f1b713afec290',
#  '177c11a0e910450898b03713480fd59b',
#  '7fbd4cf80cc64f29b6f64723af729b0c',
#  '86afc0dd44354b9caae4e8e56dd0e43d',
#  '4b92788692b04b6b8418f83683c86b7e',
#  'fe126c61ffbc4b11b841e6075a33ff13',
#  '52694ddcd71349f1896e044e23dc8549',
#  '47f267eeea9c4facbcbd489c33ca2136',
#  '53cb158d3f70410591d69e602bd2d908',
#  '29369869fe2d493b87233563559bc7a6',
#  '8e4b6a0068d346ac9bd59549cc60c6fc',
#  'df3d9cc37fa94bfa8ae643d553d0521c',
#  'd4946b9b518b4049bdaa3aeb1030d143',
#  'e7f596c002c04e268739c8b3be12fdf4',
#  '876eb2745d884f748f4082738db76c4d',
#  'f4982a4195cc4f05b272240852a88214',
#  'e099a1d6dead44f995a9984939e6fbe5',
#  'c66d96d6c55b45558adf4eab8a587082',
#  '2ddf1edbc21d46d9a1f5bfc0a6fcbcf1',
#  '6f570b9c6b614bd4be3ff2d81e4bbc38',
#  '7c442c1fe1384d2dbd82e9971b8b70f4',
#  'd96ac6ffefb142dd9294d54da946b40a',
#  '4edee22cac354858a62a7920540b8bd5',
#  '7651007750964fa8a3bbee13f64ec88b',
#  'e3b5cd61345f46eda4b44714c7150bc3',
#  '6976b0ed5bb04316b8b4f2b4dd7903d3',
#  '12a1b964b7bb474bbceb1c6522db4709',
#  '09a0a11f7d0c4923b53aa68fa5cea030',
#  '82d557517f4a4799a5d2e835b988cade',
#  'd5233d1b04c544d488358e24b519b0bd',
#  '54ecea9a9cb049bbb6d7cc2d4141a5a2',
#  '376a98fa1e124ad09e0a11a0c285326e',
#  'ba127be357c441cfa2ea60a321c9f05b',
#  '05646a8a568f47e294ee8ca5543026ad',
#  'a5f3b72d10a142bba6ce0f163453d75e',
#  '41469bbab7824d90a126b9c4098c9ba4',
#  'a4a4f30e236748ed84eeef76aff0bbad',
#  '2c262618f6f44c57954e756ecba14cdb',
#  'f649c82b836b4d52a6dc414ae5fd0af0',
#  'c312de0336f3491d9cc358b5563d7baa',
#  '3595ddfd8200448785a7ded4212d96c8',
#  '75e5dc8bf4524c99a4b30005db373c7e',
#  'ad52d3e28b3a4ddd9484022892611212',
#  '96b0370079714c05aee141719e577180',
#  'bacd5807ab1f4a4a824e526c8f2cbb6a',
#  '09b7aabbbaf54f37945867d24e508dc6',
#  'e21eb06eff01413490bd932e390364d4',
#  '70479164e4ff47dd926c121a8959e6ca',
#  '51df7822b19a46d080862fc36abce046',
#  '61ed147213f14ee4879ccf29fce0debd',
#  '2bb6c3e1ccec4b3b86ad0991f8aea785',
#  '52d96d33384b4d8785fcf06c2e45a01c',
#  'eb52d9cc140047be96e7d51f79933d6b',
#  '6d4107374a354315a2f96464376c3b5f',
#  '85a66b8f21e248b99b098b05910ae6f9',
#  '36db0370eea847c68eff67df31f52d78',
#  'fbc8a14d0a44488bafe5045591abb993',
#  '99db16254e5740b2aa52538fb7e787bb',
#  '72ac8f4e6046469eb595d8d8de3605b1',
#  'a682eb97856c4de28e4bdf737a1ad9a1',
#  '784acab97cc94e63b06eb278010433ae',
#  'cbded625fbf4468fbbcc79127e628680',
#  'd77d5ac4e7454898bce908754d260956',
#  '73ce834a0fd44b8bb8cfced721c0ba6e',
#  'e03324dadc644f9facd0700217ef15b0',
#  '46aac46926b446a181c3a238629fbd13',
#  'f68be240240d4301846efa0c0f5a9f72',
#  'd7863a8dea394583b3f226e24cb70acf',
#  '1b7f4d25b5cf4ad88f7bb172ca6ea933',
#  'e99ea669a67e4cfc9c8f00a53463fa0a',
#  '5e6ed975f2434d04ad062cef6da9f56b',
#  'a4b4406083794aafaa514bd0a2d72f5f',
#  'a58417a5c3ea4030b8bfdeda4cb651e1',
#  'a3eccac83341440a840021b0a03b909f',
#  'b6850185aeb84a058e20239503907f01',
#  'ca27ebb51ca244f68447137abc492979',
#  '63a78decf20e4a6c8977bf99321c98cd',
#  'e5d4d82d7d7f49afbc8f4599a031f134',
#  'c38af58f19d04164b85eb77cdd214868',
#  '74d21397c7c6468ab77ad5131560f16e',
#  '0e263d3cb45c48dd954c16ce6ac86536',
#  '3a269b7dc1ca4854884db23e694565c3',
#  '6a198319ae0f401a924a25bf7c9d1766',
#  'd339f2c39850422db01d1e5d0847c399',
#  '215a83ab3bfc4a0585530887b31c0cca',
#  '2cf01ca4979d4d83a6dd71c6f1e1d4cb',
#  'ed5c403f759f428cbb971348fd663354',
#  '0655947729984e39ae1c947771615b18',
#  '2f75310331194dc4a39f32e7a3eb7975',
#  '9f11dfcae5fe46ca89d5b8acaa27bf42',
#  '4edb8382913f4a91923a1fef3faedef4',
#  '80fcbfab14c04d9582c7d1f896bc4981',
#  'cedae36bc2ad4962b5bf97f782222e8e',
#  '7a531e2ffd64497cbac092a773174c4c',
#  '9b6da5cb4b6a478f820d5ce9121009cb',
#  '8b1abba775694349a7b79e7d3f22ac96',
#  '045d1928b0874dc3b531ee2f32a232eb',
#  '7f7b3ef2dd264c18ab3aacb20b31fa28',
#  '72a5a0a7113d42a082730f4480bfa741',
#  'a4d3a3f9e5a447c791120347ee647708',
#  '643b78c78b084075a7065b5b4e5b0efa',
#  '808ae49200bb4b1b829f7da499d91191',
#  '3eae4ebf71634359a37e362ff4d32f7c',
#  'd3782a306d1f43bc95faaaa07bcb981d',
#  '3cd61071442b4055b4e5c27967fe155b',
#  'a365b2c94dd04709bb45522454f19077',
#  '82744653593b4d8c9f76374a94421148',
#  'effbd3961393407bb4321ece04d0924c',
#  '1ac207590e534f009b81479b6a11c1bb',
#  'bd44bc8f02a146508e538fe1556747ed',
#  'c51ae7d39dab467784ad5ae3a492c480',
#  '4a29cbe3075f4ba9b2285e12064c7fdd',
#  'ca25b152920e45fea541ccd363476ea1',
#  'a66ebc091d594792b5789d4b16776489',
#  'e72589f5064142ecb34e018eee500986',
#  'ab57011c79f54623bfafed6ea8ce58d3',
#  '25133cf8f57645df9fedac4ac09ef2c3',
#  '8bfbbec56b4144dfa05190b733eb33c2',
#  'c4c5589c74214671919dc7e18331aa7d',
#  'd33156150be34ee28916db553b3f964b',
#  '9a38ef16edac4094b15f60fb6cf55a77',
#  '89c1f3115b374e6b83b32fe236a7b994',
#  '6b5a4883ddfe468ca247f2368a343c6a',
#  'f0b6afc32f754dff8f42bd38695f17dd',
#  'dff04ef0e90c4918ac6ff3a4ffc353fd',
#  '9fe56b9b3bb7439eb70a2d86b8d9685c',
#  'a0696570b5fa4058b98238ada29b0dd0',
#  '649439cd39bd49bba2a4bb0fca167fae',
#  '61a6b68c11c74c4995d9d34f39f44eaa',
#  'd0e2b41bca0d47bd8a2f3c76d95ab58a',
#  'e89b3f4b62e54c60a90358a23f156ab9',
#  'ced66a89deeb450784ea36008eb452a9',
#  '3e06a7d64b7c42f992f27e7262c254d4',
#  'abd737a2eead43fda68a19f6080fe03f',
#  '7de87aea350f4bc1b38638480d7df518',
#  '9df86ec472d2419a98c3bbac768db952',
#  'b033f57074a2469688d7a0d2dc68f457',
#  '1219ee172e2040b4923a1ad34efca66c',
#  '9e1a5cc11bde4f909d67da882dfdab6a',
#  '7deadc6f1bd04e2dbfae40c3dcba1108',
#  '27af0882db0044b7b3208295612d982d',
#  'c0e37b4b70fe4a7ba6a0d334e2f5ed8f',
#  '73708fc613ad418bac1496679eec6875',
#  '1e7978cef5334bb4a47a462397f18d18',
#  '48260f5738014efa986c4d3253827ccb',
#  'dd345014b9614906ae7b2507778bfd2b',
#  'f99cdbcbf72b44568a8fae6a1f0ae7fb',
#  '6d7f3148a19c4e4a83d6759521923bdc',
#  '6dda7ff7ffe242658a65db0fd8ed4c64',
#  '93dc11cd70d44bedb67e69f74f743ee9',
#  '429cf131caad48bfae7a36697d38122d',
#  'c208f555041445e3b1d9e8a119c1cb68',
#  'e5a5d3e0083a48b78e2c29258d9d5c29',
#  '10bfe478575f423fa06a09a556031f53',
#  '12b97db779ad4d64b160688a0018fd73',
#  '078503caefb34a5dace95a1d8aeff60a',
#  '6c8e0c4e74e742d6bf3c3b495450dccd',
#  '604eb7216cee476c91bdf2232044e442',
#  '3d3a6e9bae6044a484939c4edbba94b5',
#  'c56ddf3cdfbb452188ce117cf0bc9c94',
#  '2a7c055f00564272ab9b16ecdbbc3358',
#  '250f0e1bec85488b877fb48da84ced32',
#  '83ee0138925e4e3a8814c107e62f5482',
#  'dc9d05e9421f4ddb85cf4838b489b463',
#  '75e79730adf64faea7c7a8b0e325bf2a',
#  '22d01b1886a249c8ae6101316af4e8ce',
#  '95abcf1853aa4b41b9e0959223759329',
#  '0cbaeef2f4b945b4a3d78d38688daaaa',
#  'f099cfd2593847cc8af7a4480df50dda',
#  '202e7d2c939c4008a240c4e01b7aad63',
#  'aaf4b52e919844f58056309940a4775c',
#  '6e657b91dfe24235997058791bbe57eb',
#  '01024d4391b949b59886f3c8fb141a46',
#  '12f8b3b8672e47d98db0aaf15841a421',
#  '93ecc35ef01b40358127a2d72ca51716',
#  '63b5573bb95041b8bc6130e702de0cac',
#  '137f50aaa8eb4b9096d4f76111dddc4b',
#  '8875f2c4a5524b878060bb5a6f8e2518',
#  '624c72f8360d4c53919a9e50c0d5a546',
#  '97517dff050a495db07c43d2b193707e',
#  '34799008f67b4ed7844f21bd8295fa99',
#  '3720c4f6f5c643138941205678bd03f0',
#  '8dd4aee5b18a402e97d20f1e3ef025da',
#  'ffa04195a66248ee93b2395fad3363fb',
#  '2210ef359c2c4df7bfbf15c4dc4c3401',
#  '04c6e1ba34754f2caec307afa5e88398',
#  '8dbccc6ef1fc4ce8a22642cde3df46a1',
#  '8870085ff0bf4f22a976d12705ebb6ab',
#  '090e6fa5d8e8418d8685347e4cb31765',
#  '7ec1b7df7331461aa44de7475c9d77ad',
#  'ad1c9ee87ea54ce09a42ffe0085ae20f',
#  'cf8fcd1351e5460c93fb195af5d5d67e',
#  '2c0274a592c1495a969ed9fea13d07b9',
#  'f11ccaad7c124ebcb30e5293989e45f7',
#  '9cc57d86b0d246e3b46d1de956a17033',
#  '975e09ef0c4d4781bd1ba9d5a2d4ead0',
#  'e5e65a4995c94bec80f38c062fef411d',
#  '9ec9f4ef434c4794862765e0703e1810',
#  '36d94083c59a4d4fbd55e15394e78023',
#  '1762e726096345c28fb7182669380115',
#  'd25a7f590df94f65ba51dceef32c49f7',
#  '91aa455888ee4b439160ccc5cd38f480',
#  'df35c72384a7437cabe12e4a683bc9f7',
#  '6afbbcfa338b40bca12c15a97c2acacc',
#  'b9c7c82db8244df99cfef67bc7cab905',
#  'f00f1015ab144adcac6dbe66fbfde769',
#  '539cdd74910e42fa83c99009738cf0a4',
#  'fe69d0aa644a40e19862f359789ff98f',
#  '71bb1d8a2d8b497aa1bc54ce9e912135',
#  'd3eff21d4ad44a1790884d615f3e6801',
#  'd1fe1550a1ae407e9a1b74c7a2744e66',
#  '3cbaadd5cedb4794bbbf1ddd401e84c2',
#  '59a570251b66496a961596df6c047e1d',
#  '274f6ad09ead42baa3879de2e42712bf',
#  '575de2a747a34e0182fe12cca8824171',
#  'dcb110fa5bba4528b00a6906fe545221',
#  '750ed9e24b2a4445830954977ee42025',
#  'e942122ebeaa40df9e3bd85aee228ee6',
#  '713db65609ae429c829982d9fa0d9539',
#  'a1106c2cb7f54c8f8cd2577c57b31ca1',
#  '3588edb1e09745b4905d542d9bd7f3c9',
#  'df738f187fd949439e586280f2a02bf6',
#  '8726752d511945368f77ee66e50a17ac',
#  '49e9d1b9426a4bb58c28071c958fad0b',
#  'bb9ce6cbfa38428abf5ee4149ba9fcfe',
#  '5178844899e04c0b9bf73e1efb635698',
#  '414b3e01a912492dbd845a10096e1fa9',
#  '207e0b3a003444e79f9a084ab73385a2',
#  'a4f9f1457c4f40a0ba4d481df746b45c',
#  '2a5d7bec34c94d7691394b67198bb7f8',
#  'b4a251a0a9b44abd9f48392309cd5b11',
#  'b7411a51dc234530931c3df41b2764e8',
#  'b369080861f844d996187151a9dac9fa',
#  'b49583ebae9e47c5b58143866978bbda',
#  '86acfb8cfcf54d5dbfe57e08a0aac291',
#  'd1f8b11740cd4af1bff5f4b829cce861',
#  '2197be2ef37c4bffaa455164d6f89a31',
#  '92f6349180464ab9b5470ffc06a73257',
#  '2fa94c6ef61f4ef9a60989769c2a39bf',
#  'bc1651192f374cabab26329f6587b39b',
#  'a8cac6d365a4418e9fd8e33d8f2e094d',
#  'efe2c57bd1844ef58436945e224d89a8',
#  'c86b07d413c64efa90b4c66aa04eaba9',
#  '9110919659084563a50f22420edfb57f',
#  'ff82382d421a455bb7af5663d3094d7d',
#  '3ee898b252e24f8e93384a1212b5f0be',
#  'a22c457ff9794cb4a5b2bdc4be09082d',
#  '4d27b6edd88d43439b896e4b82d7301f',
#  'b8e3b7db1d8246f5a2f2baecfb470c1d',
#  'be38e53a915f478ba9e94d3114ad26aa',
#  'be2be045d00a4799a6ef6b485913fb5f',
#  'e670d4d3ccc74f57a41a5c2f193b2f12',
#  '61c2f62859a24b32901e5201cc1144b9',
#  'b8fb78f32c60447d8a02ac0ba520cbf5',
#  '919ca32e996546ca896de1fb4741b5c7',
#  '160027b678dd4eca96bda25eb7492c16',
#  '920764334db2432abf403853da377372',
#  'eee287acbb144d77b0bde80449b27e13',
#  '1e8fdf80a5b743a78301a4b948eddce3',
#  'e8c417ea141b4851a41568f832977982',
#  'a4dd7e03469a412f98e5329f7cb40d08',
#  'b7ec8b3726db4d588496cca0eda7da04',
#  '07b59b27c5504b40b0d7bbb7ee790efa',
#  '7011e8ac50fe43f692597ef212d68517',
#  '46ebf7920b784e61bae5df87eef7d3c5',
#  '970f95588d76462299f77fd23d4b1b12',
#  '62e53a81a23448f9825c7f096622ed56',
#  '6f90ea0828674c2a8871a0ed7d3b30db',
#  'e1ba324a69f3418ebe115e0399c2d955',
#  '2b76519468b04b1b999b6ceb0c14054a',
#  'd71541935c234d01906088da0db51851',
#  'a8295d61a602471798946e0ce9972131',
#  'b0618ccedced4eaca40e44c86eee4c1a',
#  '24d4772da81f4976bc0806d96437af9a',
#  '028728995a61478cb63b3de9f8bc5ef6',
#  '3f027ec34bac4042aa9705fdbffd4d49',
#  'b03e282715ee429d8fac4f1e4a75d028',
#  '068800b66e414f1ab5b1291e8aefee36',
#  'f29111a0e084460f999973a4601ba655',
#  '8e183ccc74bc46b7aab2b778bedb9a24',
#  '977e034c4de841329ed988d578bc1bf8',
#  'ce2def1bc6014915974667cacb389f12',
#  'f0ba6111b6924877838c9b63e7d86070',
#  'c6e9afe6678140279a6677712522940d',
#  '68ad26810de04ef8bec89cbe5d7324fd',
#  'c8b165ef4e414a33b45bb30006e7c51f',
#  '428a5b734d594851ac59383a2c282f7e',
#  '9ae33b3b9b4d4200afbd9d1b7041c7c4',
#  '943a66ee9b7e4ad993aac53d09635a0e',
#  '3e126f4d2c7148ca80a66b02dfbe189d',
#  '68de9ecbe31245a486142182e044218f',
#  '0ed52d867b0e402fa4faf5942a5e8680',
#  '5a1cbd6564854615954de2281bc506ce',
#  '78fba5d5696441baa06a0980ed9aecf6',
#  '2b68344674144845883ee60494481bed',
#  '17335e6aee72458290d28e7f0846c8e7',
#  '643cdb4fd2f3419a8dff979e94d2dd35',
#  '86527e1bcf854e89964100321c7326b9',
#  '477be5eb0c204e719fe12416affbecb0',
#  'ceba346fa9c544988bbddf884678d7fd',
#  'c6e1beb6fb344082ab3a3eff12d34b60',
#  '56dc83e6c5b44f38ae1302af06e6506f',
#  '7be584795dc44dc7b1d545d8f41523fc',
#  '126e1c31ea314f56bca6f46020f87970',
#  'd5b33f56aee445f9aa61f272a3cea219',
#  'f9b1248d6670403e863ddf60a82c533a',
#  'e0db0f9a9abd473f9cc0d854e79b756b',
#  '0eccb2aca9284c47bb31530a6c886035',
#  '6cbefc51fdf4467faf5c1f051a3a04f1',
#  '1dd6fd24129949848523ed61138b953b',
#  '961a04b7c20d4c0d853dc98736a23684',
#  'c68a737ece39465b88ee02453732f28f',
#  '4b51606caa274db29dbcf06eb0cfddf7',
#  '9d1fc5f4ee97457ca484a78bdca260c0',
#  '3e3c8a6e5a474564bae05537b1f51e59',
#  '3217102cc3b54449bacf029df0ebf9a9',
#  '741f5fa14f4c4fa692a73b1fddbf51d2',
#  'f15d8bb28348421995e57400a0c943f4',
#  '5a0d1d33c8fe4d44b4af880050ab0616',
#  '3c6b9a08c41340379299cb64cd5939b8',
#  '95564377f79540bda52e33a246452e8b',
#  'ecfeca6af1f14ce0a21a192f40b4ea03',
#  'cfad0bce61f940ecaf18d356778187f9',
#  '4d7512f8c1d446dcb54a2036cc94cd38',
#  'e1904e56dcbd4dc68d554bd31424b496',
#  '46b6103c9ba74f889c66da1a4a2fe1c3',
#  '9d65d58161dd463880245aca8e8bb2df',
#  '39055d4a57b044f38fbf0166b7e36eeb',
#  'a7956050cd1e4c1fbeaf881389752496',
#  '56ed51c378b3458c8b2506649a9ff7a8',
#  '885063c81d9048f7b4ec8dba46c82848',
#  '0fdea0e8fa464462bb9d5d36ea4fa5eb',
#  '346eabfed1f7480288a30ee066e6e937',
#  '547dc099b92543b88261441ffbf30f07',
#  '85228014b3b04ad4912cff298e80805a',
#  '08a69e7d7bb442bd9ee16ce95bf1f601',
#  '9cf507016eaa4ff88967dab193f0960b',
#  '823e3a5633ca4e16bd96b3611ece78c9',
#  'f639aca2cbea4f2f83f28272d39ffed1',
#  '27b99a5f9d90468ca2e8b6f8756225a1',
#  'c68c9da6bba745b7bd6011b3977837db',
#  '9477cac108b44597bf22daff5ee0d8b6',
#  '5730f67f11b64537adac7256eb828867',
#  '803ac286072644ac8b590129410b25fc',
#  '89455ca4bfe643e69e72858305bb7f7e',
#  'ee3a2611b5eb497f8050e84c7afce9b0',
#  '4451000a2cbb47f98fd2e38e8a6ae195',
#  '26907d7471f24a8f95df58378a099238',
#  '700e2760da0741faa2a5d0791bf16e40',
#  'b417fd12b8754ddfb620d4ddeef34483',
#  'fb825d57d1494659908e43a78ed8108e',
#  '955da4f390274b7e8ea17d2efc04c37b',
#  '2fd48f1ece6449738ff8b17c7b3de120',
#  'b946a161116e4c1fa2d9ec54c3d507e1',
#  '08555ad004ac4ce291030948d9144e52',
#  'cbb38f7cfe254aa4bcaf5ea0769c4960',
#  '1d9ffc5f0d4c4bef985ee515c201cbcd',
#  '734c786de5ab4d53bc7d289d0c7a50a9',
#  '77039ac6954c40b18abe8ed9617a3d79',
#  'a4d48637d5d84cf998b5a5d4301d11e0',
#  'd81f7eabc4844df49b684460669aca29',
#  'ac67e0d8302e462f9042aad957b7e317',
#  '2b3fbdb768f340e381bcfe7f06507e92',
#  'f62a3d7d30314bfbbf6c6a21b11adb07',
#  '3899f3c73e84455da91ca5df8dd9492f',
#  '04e460d14c4c449a8605da2b84eb26d0',
#  'fb732a597e9d4cedae72ee04bf3c0fc1',
#  '585c7e4d80314e348bd6bd742b5a9a60',
#  '6502846a1de449c5ba9e50155834a692',
#  '68cd00b9475b46bca8272d2bdf9aea8a',
#  'd190989784bf4bbba355321941937bea',
#  '0b091dfb7b6045d095b17e3b14826a34',
#  'fbec95110ad94bfe9f93c8913bd4c92c',
#  'bda6e664894c4479a5a2862ddb44e27a',
#  'bd1fd430e0d740d78b03f144a1fb876d',
#  'ff939fd5f9fd4f6f969ea12d3591a763',
#  'c9243bda8e1343cf86e7a2701022b82e',
#  '7243709f4f4840f18feb801b20d521fb',
#  'f8cd131fc7fa49a9bee245f317992d22',
#  '5763ea86fcfe4920b5ca3ec54e468104',
#  'bed49574c81b4a0e81f08a3aca9bc3cb',
#  '76f1b401ce9a4f91bd1c5da0674e7d29',
#  '0e060e6a79664b749a5d461e0c4a807c',
